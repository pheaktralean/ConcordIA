# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Import dataset

# %%
df = pd.read_csv('./data/Nutritional_Programming_West.csv')

# %% [markdown]
# Drop hashed columns

# %%
hashed_col = [
    'Surname', 'First Given Name', 'Birth Date (YYMMDD)', 'Month of Birth',
    'Day of Birth', 'Social Insurance Number', 'Provincial Health Insurance Number',
    'Home Address', 'Home Address Postal Code', 'emailaddress1_DC', 'mir_primary_phone_DC',
    'Full Name_AC', 'Client Preferred Name_AC', 'Client Supervisor Name_AC', 'Client Address Line 2_AC',
    'Client Email_AC', 'Client Phone (Main)_AC', 'Client Phone (Other)_AC', 'SADDR2_YD', 'Member Name_YD',
    'License Plate Number_YD', 'Property Code_YD', 'MemberFN_YD', 'MemberLN_YD', 'C_Prefername_HB',
    'C_Unit_HB', 'C_mPhoneType_ID_HB', 'C_mPhone_HB', 'C_sPhoneType_ID_HB', 'C_sPhone_HB', 'C_email_HB',
    'hbaddress_HB', 'e_FirstName_HB', 'e_LastName_HB', 'e_Phone_HB', 'e_email_HB', 'RG_Location_HB',
    'UpdateBy_HB', 'Associated Contact_CC', 'Location_CC', 'Current Service Location_CC', 'ClientName_CU',
    'Phone_CU'
]

df.drop(columns=hashed_col, axis=1, inplace=True, errors='ignore') # axis=1 refers to columns

# %%
df.head()
# Out:
#   Unique Record ID              Sex Marital Status  Year of Birth  \
# 0         9036 CCU  Cisgender Woman         Single           1963
# 1         9038 CCU  Cisgender Woman         Single           1958
# 2         9038 CCU  Cisgender Woman         Single           1958
# 3         9038 CCU  Cisgender Woman         Single           1958
# 4         9038 CCU  Cisgender Woman         Single           1958
#
#    Birth Province / Country Code  Home Province Code Creation Date  \
# 0                            NaN                 NaN     7/20/2015
# 1                            NaN                 NaN    10/23/2021
# 2                            NaN                 NaN    10/23/2021
# 3                            NaN                 NaN     3/18/2015
# 4                            NaN                 NaN     3/18/2015
#
#    Last Modified System Registration  statecode_DC  ...  WithdrawalDate_CU  \
# 0            NaN           Piourette           NaN  ...           2/5/2018
# 1            NaN           Piourette           NaN  ...         10/23/2021
# 2            NaN           Piourette           NaN  ...         10/23/2021
# 3            NaN           Piourette           NaN  ...          3/18/2015
# 4            NaN           Piourette           NaN  ...          3/18/2015
#
#    ReasonForWithdrawal_CU    Citizenship_CU  \
# 0                Deceased  Canadian Citizen
# 1           None Selected  Landed Immigrant
# 2           None Selected  Landed Immigrant
# 3           None Selected  Landed Immigrant
# 4           None Selected  Landed Immigrant
#
#                                 Primary Diagnosis_CU  MODIFIEDON_TR  \
# 0                                   Gastrointestinal            NaN
# 1  Hepatitis A, B,or C. please specify under comm...            NaN
# 2  Hepatitis A, B,or C. please specify under comm...            NaN
# 3  Hepatitis A, B,or C. please specify under comm...            NaN
# 4  Hepatitis A, B,or C. please specify under comm...            NaN
#
#    ClientAddressCity_TR  Citizenship_TR  Program Name_TR  \
# 0                   NaN             NaN              NaN
# 1                   NaN             NaN              NaN
# 2                   NaN             NaN              NaN
# 3                   NaN             NaN              NaN
# 4                   NaN             NaN              NaN
#
#    DischargeDateY-M-D_TR  Encounter Status_TR
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                    NaN                  NaN
#
# [5 rows x 145 columns]

# %% [markdown]
# Drop columns where all values are NaN

# %%
df.dropna(axis=1, how='all', inplace=True)

# %%
df.head()
# Out:
#   Unique Record ID              Sex Marital Status  Year of Birth  \
# 0         9036 CCU  Cisgender Woman         Single           1963
# 1         9038 CCU  Cisgender Woman         Single           1958
# 2         9038 CCU  Cisgender Woman         Single           1958
# 3         9038 CCU  Cisgender Woman         Single           1958
# 4         9038 CCU  Cisgender Woman         Single           1958
#
#   Creation Date System Registration System_CU  ClientID_CU  City_CU  \
# 0     7/20/2015           Piourette       CCU         9036  Toronto
# 1    10/23/2021           Piourette       CCU         9038      NaN
# 2    10/23/2021           Piourette       CCU         9038      NaN
# 3     3/18/2015           Piourette       CCU         9038      NaN
# 4     3/18/2015           Piourette       CCU         9038      NaN
#
#                        Program_CU    Race_CU Culture_CU    Religion_CU  \
# 0  Nutritional Programming - West  Caucasian   Canadian  None Selected
# 1  Nutritional Programming - West  Caucasian   European      Christian
# 2  Nutritional Programming - West  Caucasian   European      Christian
# 3  Nutritional Programming - West  Caucasian   European      Christian
# 4  Nutritional Programming - West  Caucasian   European      Christian
#
#   PreferredLanguage_CU WithdrawalDate_CU ReasonForWithdrawal_CU  \
# 0              English          2/5/2018               Deceased
# 1              English        10/23/2021          None Selected
# 2              English        10/23/2021          None Selected
# 3              English         3/18/2015          None Selected
# 4              English         3/18/2015          None Selected
#
#      Citizenship_CU                               Primary Diagnosis_CU
# 0  Canadian Citizen                                   Gastrointestinal
# 1  Landed Immigrant  Hepatitis A, B,or C. please specify under comm...
# 2  Landed Immigrant  Hepatitis A, B,or C. please specify under comm...
# 3  Landed Immigrant  Hepatitis A, B,or C. please specify under comm...
# 4  Landed Immigrant  Hepatitis A, B,or C. please specify under comm...

# %%
print(df.columns)
# Out:
# Index(['Unique Record ID', 'Sex', 'Marital Status', 'Year of Birth',
#        'Creation Date', 'System Registration', 'System_CU', 'ClientID_CU',
#        'City_CU', 'Program_CU', 'Race_CU', 'Culture_CU', 'Religion_CU',
#        'PreferredLanguage_CU', 'WithdrawalDate_CU', 'ReasonForWithdrawal_CU',
#        'Citizenship_CU', 'Primary Diagnosis_CU'],
#       dtype='object')

# %% [markdown]
# Group by gender and marital status

# %%
grouped_sex_marital = df.groupby(['Marital Status', 'Sex']).size().reset_index(name='Count')
print(grouped_sex_marital)
# Out:
#   Marital Status              Sex  Count
# 0     Common Law  Cisgender Woman      1
# 1       Divorced    Cisgender Man      4
# 2       Divorced  Cisgender Woman      1
# 3        Married    Cisgender Man      2
# 4  None Selected    Cisgender Man      1
# 5  None Selected  Cisgender Woman     11
# 6         Single    Cisgender Man     26
# 7         Single  Cisgender Woman     24
# 8        Unknown    Cisgender Man      4
# 9        Unknown  Cisgender Woman     16

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Marital Status', y='Count', hue='Sex', data=grouped_sex_marital)
plt.title('Nutritional Programming by Marital Status and Sex')
plt.show()

# %% [markdown]
# Group by gender and culture

# %%
grouped_sex_culture = df.groupby(['Culture_CU', 'Sex']).size().reset_index(name='Count')
print(grouped_sex_culture)
# Out:
#                   Culture_CU              Sex  Count
# 0   Aboriginal/First Nations  Cisgender Woman      1
# 1                    African    Cisgender Man      2
# 2                   Canadian    Cisgender Man     30
# 3                   Canadian  Cisgender Woman     24
# 4                  Caribbean  Cisgender Woman      4
# 5                 East Asian    Cisgender Man      1
# 6                 East Asian  Cisgender Woman      1
# 7                   European    Cisgender Man      3
# 8                   European  Cisgender Woman      7
# 9   Preferred not to Specify  Cisgender Woman      3
# 10                   Unknown    Cisgender Man      1
# 11                   Unknown  Cisgender Woman     13

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Culture_CU', y='Count', hue='Sex', data=grouped_sex_culture)
plt.title('Nutritional Programming by Culture and Sex')
plt.show()

# %% [markdown]
# Group by gender and citizenship

# %%
grouped_sex_citizen = df.groupby(['Citizenship_CU', 'Sex']).size().reset_index(name='Count')
print(grouped_sex_citizen)
# Out:
#      Citizenship_CU              Sex  Count
# 0  Canadian Citizen    Cisgender Man     37
# 1  Canadian Citizen  Cisgender Woman     43
# 2  Landed Immigrant  Cisgender Woman      7
# 3     None Selected  Cisgender Woman      3

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Citizenship_CU', y='Count', hue='Sex', data=grouped_sex_citizen)
plt.title('Nutritional Programming by Citizenship and Sex')
plt.show()
