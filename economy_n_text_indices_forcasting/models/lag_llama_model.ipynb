# %%
 #Run this cell FIRST and ONLY ONCE

# 1. Downgrade numpy to fix the "dtype size changed" error
# !pip install "numpy<2.0" --force-reinstall
# Out:
# Collecting numpy<2.0
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.3 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 92.1 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.35.1 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
# 2. Install GluonTS and other dependencies
# !pip install gluonts torch pandas matplotlib seaborn --quiet

# 3. Clone and install Lag-Llama
import os
if not os.path.exists("lag-llama"):
    # !git clone https://github.com/time-series-foundation-models/lag-llama/

# %cd lag-llama
# !pip install -r requirements.txt --quiet

print("\n✓ Setup complete! Now run Cell 2.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 22.2 MB/s eta 0:00:00
# Cloning into 'lag-llama'...
# remote: Enumerating objects: 508, done.
# remote: Counting objects: 100% (183/183), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 508 (delta 155), reused 114 (delta 114), pack-reused 325 (from 3)
# Receiving objects: 100% (508/508), 286.89 KiB | 1.63 MiB/s, done.
# Resolving deltas: 100% (253/253), done.
# /content/lag-llama
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 35.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 105.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 101.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 21.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.1/778.1 kB 61.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 67.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.4 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.12.0 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# plotnine 0.14.5 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.
# xarray 2025.11.0 requires pandas>=2.2, but you have pandas 2.1.4 which is incompatible.
# mizani 0.13.5 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.
#
# ✓ Setup complete! Now run Cell 2.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import os
import warnings

# CRITICAL FIX: Patch torch.load ONCE at module level
# This prevents the recursion error from multiple patches
import torch.serialization

# Store the TRUE original torch.load (from the module, not torch.load which might already be patched)
if not hasattr(torch.serialization, '_original_torch_load_backup'):
    torch.serialization._original_torch_load_backup = torch.serialization.load

def safe_torch_load(*args, **kwargs):
    """Wrapper that adds weights_only=False by default"""
    if 'weights_only' not in kwargs:
        kwargs['weights_only'] = False
    return torch.serialization._original_torch_load_backup(*args, **kwargs)

# Apply the patch
torch.load = safe_torch_load
torch.serialization.load = safe_torch_load

print("✓ torch.load patched successfully")

# GluonTS imports
from gluonts.dataset.pandas import PandasDataset
from gluonts.evaluation import make_evaluation_predictions
from lag_llama.gluon.estimator import LagLlamaEstimator

# ---------------------------------------------------------------------------
# 1. LOAD AND PREPROCESS DATA
# ---------------------------------------------------------------------------
filename = '/content/macro_index_data-3.csv'

if not os.path.exists(filename):
    filename = 'macro_index_data.csv'

if not os.path.exists(filename):
    print(f"❌ Error: {filename} not found. Please upload your CSV file.")
    raise FileNotFoundError("Please upload macro_index_data.csv")

df = pd.read_csv(filename)
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
df = df.asfreq('W-SUN')
df = df.ffill().bfill()

# CRITICAL: Convert *all* numeric data (ints + floats) to float32
# This avoids Long tensors inside Lag-Llama (which break freq_mask).
num_cols = df.select_dtypes(include=[np.number]).columns
df[num_cols] = df[num_cols].astype('float32')


print(f"✓ Data Loaded. Shape: {df.shape}")

# ---------------------------------------------------------------------------
# 2. FEATURE SELECTION - Only use POSITIVELY correlated features
# ---------------------------------------------------------------------------
target_col = 'number_of_people_MA4'

# Calculate correlations
numeric_df = df.select_dtypes(include=[np.number])
corr_matrix = numeric_df.corr()

if target_col in corr_matrix.columns:
    target_corrs = corr_matrix[target_col].drop(target_col)

    # ONLY select features with POSITIVE correlation > 0.3
    # Negative correlations can confuse the model
    threshold = 0.3
    selected_features = target_corrs[target_corrs > threshold].index.tolist()

    print(f"\n✓ Target Variable: {target_col}")
    print(f"✓ Selected {len(selected_features)} features with POSITIVE correlation > {threshold}:")
    for feat in selected_features:
        print(f"  • {feat}: {target_corrs[feat]:.3f}")

    # Show excluded negative correlations for reference
    negative_corrs = target_corrs[target_corrs < -threshold].sort_values()
    if len(negative_corrs) > 0:
        print(f"\n⚠️  Excluded {len(negative_corrs)} negatively correlated features:")
        for feat in negative_corrs.index:
            print(f"  • {feat}: {negative_corrs[feat]:.3f}")
else:
    print(f"❌ Error: Target column '{target_col}' not found.")
    selected_features = []

# ---------------------------------------------------------------------------
# 3. PREPARE DATASETS
# ---------------------------------------------------------------------------
prediction_length = 12
context_length = 32

train_df = df.iloc[:-prediction_length]
test_df = df

train_ds = PandasDataset(train_df, target=target_col, feat_dynamic_real=selected_features, freq="W-SUN")
test_ds = PandasDataset(test_df, target=target_col, feat_dynamic_real=selected_features, freq="W-SUN")

print(f"✓ Train dataset: {len(train_df)} weeks")
print(f"✓ Test dataset: {len(test_df)} weeks")

# ---------------------------------------------------------------------------
# 4. LOAD AND FINE-TUNE MODEL
# ---------------------------------------------------------------------------
# Download weights
print("\nDownloading Lag-Llama checkpoint...")
# !huggingface-cli download time-series-foundation-models/Lag-Llama lag-llama.ckpt --local-dir .

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"✓ Using device: {device}")

ckpt_path = "lag-llama.ckpt"

# Load checkpoint (now safely with our patched function)
print("Loading checkpoint...")
ckpt = torch.load(ckpt_path, map_location=device)

# Handle the nested config structure correctly
estimator_args = ckpt["hyper_parameters"]["model_kwargs"]

estimator = LagLlamaEstimator(
    ckpt_path=ckpt_path,
    prediction_length=prediction_length,
    context_length=context_length,

    # Use extracted arguments
    n_layer=estimator_args["n_layer"],
    n_embd_per_head=estimator_args["n_embd_per_head"],
    n_head=estimator_args["n_head"],
    scaling=estimator_args["scaling"],
    time_feat=estimator_args["time_feat"],

    # Turn OFF augmentations to avoid freq_mask issues
    aug_prob=0.0,

    # Training settings
    batch_size=32,
    num_parallel_samples=100,
    trainer_kwargs={"accelerator": device, "max_epochs": 100},
)


print("\n🚀 Starting Fine-Tuning (This trains the model on YOUR data)...")
print("This may take several minutes...")

predictor = estimator.train(
    training_data=train_ds,
    cache_data=True,
    shuffle_buffer_length=1000
)

print(df.dtypes.head(20))
print(df['number_of_people'].dtype)   # should be float32 now

# ---------------------------------------------------------------------------
# 5. PREDICT AND PLOT
# ---------------------------------------------------------------------------
print("\n📊 Generating Forecasts...")
forecast_it, ts_it = make_evaluation_predictions(
    dataset=test_ds,
    predictor=predictor,
    num_samples=100
)

forecasts = list(forecast_it)
tss = list(ts_it)

import matplotlib.dates as mdates

plt.figure(figsize=(12, 6))
ts_entry = tss[0]
forecast_entry = forecasts[0]

# Convert Period index to datetime for plotting
ts_index = ts_entry[-100:].index.to_timestamp()
ts_values = ts_entry[-100:].values

# Plot last 100 weeks
plt.plot(ts_index, ts_values, label="Actual Intake", linewidth=2, color='blue')

# Plot forecast - need to convert forecast index too
forecast_index = forecast_entry.index.to_timestamp()
forecast_mean = forecast_entry.mean

# Get quantiles (must be strings like "0.1", not floats)
q10 = forecast_entry.quantile('0.1')
q90 = forecast_entry.quantile('0.9')

plt.plot(forecast_index, forecast_mean, label="Lag-Llama Forecast", linewidth=2, color='green')
plt.fill_between(
    forecast_index,
    q10,
    q90,
    alpha=0.3,
    color='green',
    label='80% Prediction Interval'
)

plt.title(f"Weekly Intake Prediction (Using {len(selected_features)} exogenous features)", fontsize=14, fontweight='bold')
plt.xlabel("Date", fontsize=12)
plt.ylabel("Number of People", fontsize=12)
plt.legend(fontsize=10, loc='best')
plt.grid(True, alpha=0.3)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
plt.gcf().autofmt_xdate()
plt.tight_layout()
plt.show()

print("\n✅ Forecast complete!")
print(f"\nForecast Summary:")
print(f"  • Mean forecast: {forecast_mean.mean():.2f}")
print(f"  • Min forecast: {forecast_mean.min():.2f}")
print(f"  • Max forecast: {forecast_mean.max():.2f}")

#  selected_features = [
#     'FXUSDCAD',           # 0.55
#     'FXEURCAD',           # 0.54
#     'CPIAUCSL',           # 0.54
#     'DTWEXBGS',           # 0.45
#     'DGS10',              # 0.42
#     'woodgreen_seniors_care_text_information',      # 0.38
#     'woodgreen_employment_text_information',        # 0.37
#     'goc_long_benchmark',                           # 0.35
#     'goc_long_benchmark1',                          # 0.33
#     'goc_avg_over10y',                              # 0.32
#     'DFF',                # 0.32
# ]
# Out:
# ✓ torch.load patched successfully
# ✓ Data Loaded. Shape: (242, 38)
#
# ✓ Target Variable: number_of_people
# ✓ Selected 11 features with POSITIVE correlation > 0.3:
#   • goc_long_benchmark: 0.347
#   • goc_long_benchmark1: 0.330
#   • goc_avg_over10y: 0.316
#   • FXUSDCAD: 0.555
#   • FXEURCAD: 0.544
#   • DGS10: 0.419
#   • DFF: 0.316
#   • DTWEXBGS: 0.451
#   • CPIAUCSL: 0.541
#   • woodgreen_employment_text_information: 0.374
#   • woodgreen_seniors_care_text_information: 0.379
#
# ⚠️  Excluded 1 negatively correlated features:
#   • woodgreen_family_violence_text_information: -0.564
# ✓ Train dataset: 230 weeks
# ✓ Test dataset: 242 weeks
#
# Downloading Lag-Llama checkpoint...
# ⚠️  Warning: 'huggingface-cli download' is deprecated. Use 'hf download' instead.
# lag-llama.ckpt
# ✓ Using device: cuda
# Loading checkpoint...
#
# 🚀 Starting Fine-Tuning (This trains the model on YOUR data)...
# This may take several minutes...
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: IPU available: False, using: 0 IPUs
# INFO:lightning.pytorch.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/configuration_validator.py:74: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:
#   | Name          | Type               | Params
# -----------------------------------------------------
# 0 | model         | LagLlamaModel      | 2.4 M
# 1 | augmentations | ApplyAugmentations | 0
# -----------------------------------------------------
# 2.4 M     Trainable params
# 0         Non-trainable params
# 2.4 M     Total params
# 9.797     Total estimated model params size (MB)
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name          | Type               | Params
# -----------------------------------------------------
# 0 | model         | LagLlamaModel      | 2.4 M
# 1 | augmentations | ApplyAugmentations | 0
# -----------------------------------------------------
# 2.4 M     Trainable params
# 0         Non-trainable params
# 2.4 M     Total params
# 9.797     Total estimated model params size (MB)
# Training: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/gluonts/torch/util.py:205: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:345.)
#   return a[idx]
# INFO: Epoch 0, global step 50: 'train_loss' reached 4.88316 (best 4.88316), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=0-step=50.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 0, global step 50: 'train_loss' reached 4.88316 (best 4.88316), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=0-step=50.ckpt' as top 1
# INFO: Epoch 1, global step 100: 'train_loss' reached 4.46873 (best 4.46873), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=1-step=100.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 1, global step 100: 'train_loss' reached 4.46873 (best 4.46873), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=1-step=100.ckpt' as top 1
# INFO: Epoch 2, global step 150: 'train_loss' reached 3.61870 (best 3.61870), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=2-step=150.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 2, global step 150: 'train_loss' reached 3.61870 (best 3.61870), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=2-step=150.ckpt' as top 1
# INFO: Epoch 3, global step 200: 'train_loss' reached 3.32185 (best 3.32185), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=3-step=200.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 3, global step 200: 'train_loss' reached 3.32185 (best 3.32185), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=3-step=200.ckpt' as top 1
# INFO: Epoch 4, global step 250: 'train_loss' reached 2.82772 (best 2.82772), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=4-step=250.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 4, global step 250: 'train_loss' reached 2.82772 (best 2.82772), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=4-step=250.ckpt' as top 1
# INFO: Epoch 5, global step 300: 'train_loss' reached 2.77085 (best 2.77085), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=5-step=300.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 5, global step 300: 'train_loss' reached 2.77085 (best 2.77085), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=5-step=300.ckpt' as top 1
# INFO: Epoch 6, global step 350: 'train_loss' reached 2.53678 (best 2.53678), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=6-step=350.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 6, global step 350: 'train_loss' reached 2.53678 (best 2.53678), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=6-step=350.ckpt' as top 1
# INFO: Epoch 7, global step 400: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 7, global step 400: 'train_loss' was not in top 1
# INFO: Epoch 8, global step 450: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 8, global step 450: 'train_loss' was not in top 1
# INFO: Epoch 9, global step 500: 'train_loss' reached 2.45598 (best 2.45598), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=9-step=500.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 9, global step 500: 'train_loss' reached 2.45598 (best 2.45598), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=9-step=500.ckpt' as top 1
# INFO: Epoch 10, global step 550: 'train_loss' reached 2.18299 (best 2.18299), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=10-step=550.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 10, global step 550: 'train_loss' reached 2.18299 (best 2.18299), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=10-step=550.ckpt' as top 1
# INFO: Epoch 11, global step 600: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 11, global step 600: 'train_loss' was not in top 1
# INFO: Epoch 12, global step 650: 'train_loss' reached 2.01983 (best 2.01983), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=12-step=650.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 12, global step 650: 'train_loss' reached 2.01983 (best 2.01983), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=12-step=650.ckpt' as top 1
# INFO: Epoch 13, global step 700: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 13, global step 700: 'train_loss' was not in top 1
# INFO: Epoch 14, global step 750: 'train_loss' reached 1.92135 (best 1.92135), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=14-step=750.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 14, global step 750: 'train_loss' reached 1.92135 (best 1.92135), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=14-step=750.ckpt' as top 1
# INFO: Epoch 15, global step 800: 'train_loss' reached 1.86351 (best 1.86351), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=15-step=800.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 15, global step 800: 'train_loss' reached 1.86351 (best 1.86351), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=15-step=800.ckpt' as top 1
# INFO: Epoch 16, global step 850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 16, global step 850: 'train_loss' was not in top 1
# INFO: Epoch 17, global step 900: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 17, global step 900: 'train_loss' was not in top 1
# INFO: Epoch 18, global step 950: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 18, global step 950: 'train_loss' was not in top 1
# INFO: Epoch 19, global step 1000: 'train_loss' reached 1.83042 (best 1.83042), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=19-step=1000.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 19, global step 1000: 'train_loss' reached 1.83042 (best 1.83042), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=19-step=1000.ckpt' as top 1
# INFO: Epoch 20, global step 1050: 'train_loss' reached 1.60989 (best 1.60989), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=20-step=1050.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 20, global step 1050: 'train_loss' reached 1.60989 (best 1.60989), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=20-step=1050.ckpt' as top 1
# INFO: Epoch 21, global step 1100: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 21, global step 1100: 'train_loss' was not in top 1
# INFO: Epoch 22, global step 1150: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 22, global step 1150: 'train_loss' was not in top 1
# INFO: Epoch 23, global step 1200: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 23, global step 1200: 'train_loss' was not in top 1
# INFO: Epoch 24, global step 1250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 24, global step 1250: 'train_loss' was not in top 1
# INFO: Epoch 25, global step 1300: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 25, global step 1300: 'train_loss' was not in top 1
# INFO: Epoch 26, global step 1350: 'train_loss' reached 1.55246 (best 1.55246), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=26-step=1350.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 26, global step 1350: 'train_loss' reached 1.55246 (best 1.55246), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=26-step=1350.ckpt' as top 1
# INFO: Epoch 27, global step 1400: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 27, global step 1400: 'train_loss' was not in top 1
# INFO: Epoch 28, global step 1450: 'train_loss' reached 1.40363 (best 1.40363), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=28-step=1450.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 28, global step 1450: 'train_loss' reached 1.40363 (best 1.40363), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=28-step=1450.ckpt' as top 1
# INFO: Epoch 29, global step 1500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 29, global step 1500: 'train_loss' was not in top 1
# INFO: Epoch 30, global step 1550: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 30, global step 1550: 'train_loss' was not in top 1
# INFO: Epoch 31, global step 1600: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 31, global step 1600: 'train_loss' was not in top 1
# INFO: Epoch 32, global step 1650: 'train_loss' reached 1.35168 (best 1.35168), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=32-step=1650.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 32, global step 1650: 'train_loss' reached 1.35168 (best 1.35168), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=32-step=1650.ckpt' as top 1
# INFO: Epoch 33, global step 1700: 'train_loss' reached 1.32339 (best 1.32339), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=33-step=1700.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 33, global step 1700: 'train_loss' reached 1.32339 (best 1.32339), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=33-step=1700.ckpt' as top 1
# INFO: Epoch 34, global step 1750: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 34, global step 1750: 'train_loss' was not in top 1
# INFO: Epoch 35, global step 1800: 'train_loss' reached 1.25831 (best 1.25831), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=35-step=1800.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 35, global step 1800: 'train_loss' reached 1.25831 (best 1.25831), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=35-step=1800.ckpt' as top 1
# INFO: Epoch 36, global step 1850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 36, global step 1850: 'train_loss' was not in top 1
# INFO: Epoch 37, global step 1900: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 37, global step 1900: 'train_loss' was not in top 1
# INFO: Epoch 38, global step 1950: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 38, global step 1950: 'train_loss' was not in top 1
# INFO: Epoch 39, global step 2000: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 39, global step 2000: 'train_loss' was not in top 1
# INFO: Epoch 40, global step 2050: 'train_loss' reached 1.15333 (best 1.15333), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=40-step=2050.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 40, global step 2050: 'train_loss' reached 1.15333 (best 1.15333), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=40-step=2050.ckpt' as top 1
# INFO: Epoch 41, global step 2100: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 41, global step 2100: 'train_loss' was not in top 1
# INFO: Epoch 42, global step 2150: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 42, global step 2150: 'train_loss' was not in top 1
# INFO: Epoch 43, global step 2200: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 43, global step 2200: 'train_loss' was not in top 1
# INFO: Epoch 44, global step 2250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 44, global step 2250: 'train_loss' was not in top 1
# INFO: Epoch 45, global step 2300: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 45, global step 2300: 'train_loss' was not in top 1
# INFO: Epoch 46, global step 2350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 46, global step 2350: 'train_loss' was not in top 1
# INFO: Epoch 47, global step 2400: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 47, global step 2400: 'train_loss' was not in top 1
# INFO: Epoch 48, global step 2450: 'train_loss' reached 1.03336 (best 1.03336), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=48-step=2450.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 48, global step 2450: 'train_loss' reached 1.03336 (best 1.03336), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=48-step=2450.ckpt' as top 1
# INFO: Epoch 49, global step 2500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 49, global step 2500: 'train_loss' was not in top 1
# INFO: Epoch 50, global step 2550: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 50, global step 2550: 'train_loss' was not in top 1
# INFO: Epoch 51, global step 2600: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 51, global step 2600: 'train_loss' was not in top 1
# INFO: Epoch 52, global step 2650: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 52, global step 2650: 'train_loss' was not in top 1
# INFO: Epoch 53, global step 2700: 'train_loss' reached 0.98926 (best 0.98926), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=53-step=2700.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 53, global step 2700: 'train_loss' reached 0.98926 (best 0.98926), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=53-step=2700.ckpt' as top 1
# INFO: Epoch 54, global step 2750: 'train_loss' reached 0.89865 (best 0.89865), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=54-step=2750.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 54, global step 2750: 'train_loss' reached 0.89865 (best 0.89865), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=54-step=2750.ckpt' as top 1
# INFO: Epoch 55, global step 2800: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 55, global step 2800: 'train_loss' was not in top 1
# INFO: Epoch 56, global step 2850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 56, global step 2850: 'train_loss' was not in top 1
# INFO: Epoch 57, global step 2900: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 57, global step 2900: 'train_loss' was not in top 1
# INFO: Epoch 58, global step 2950: 'train_loss' reached 0.81753 (best 0.81753), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=58-step=2950.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 58, global step 2950: 'train_loss' reached 0.81753 (best 0.81753), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=58-step=2950.ckpt' as top 1
# INFO: Epoch 59, global step 3000: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 59, global step 3000: 'train_loss' was not in top 1
# INFO: Epoch 60, global step 3050: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 60, global step 3050: 'train_loss' was not in top 1
# INFO: Epoch 61, global step 3100: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 61, global step 3100: 'train_loss' was not in top 1
# INFO: Epoch 62, global step 3150: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 62, global step 3150: 'train_loss' was not in top 1
# INFO: Epoch 63, global step 3200: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 63, global step 3200: 'train_loss' was not in top 1
# INFO: Epoch 64, global step 3250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 64, global step 3250: 'train_loss' was not in top 1
# INFO: Epoch 65, global step 3300: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 65, global step 3300: 'train_loss' was not in top 1
# INFO: Epoch 66, global step 3350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 66, global step 3350: 'train_loss' was not in top 1
# INFO: Epoch 67, global step 3400: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 67, global step 3400: 'train_loss' was not in top 1
# INFO: Epoch 68, global step 3450: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 68, global step 3450: 'train_loss' was not in top 1
# INFO: Epoch 69, global step 3500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 69, global step 3500: 'train_loss' was not in top 1
# INFO: Epoch 70, global step 3550: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 70, global step 3550: 'train_loss' was not in top 1
# INFO: Epoch 71, global step 3600: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 71, global step 3600: 'train_loss' was not in top 1
# INFO: Epoch 72, global step 3650: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 72, global step 3650: 'train_loss' was not in top 1
# INFO: Epoch 73, global step 3700: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 73, global step 3700: 'train_loss' was not in top 1
# INFO: Epoch 74, global step 3750: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 74, global step 3750: 'train_loss' was not in top 1
# INFO: Epoch 75, global step 3800: 'train_loss' reached 0.76405 (best 0.76405), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=75-step=3800.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 75, global step 3800: 'train_loss' reached 0.76405 (best 0.76405), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=75-step=3800.ckpt' as top 1
# INFO: Epoch 76, global step 3850: 'train_loss' reached 0.69823 (best 0.69823), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=76-step=3850.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 76, global step 3850: 'train_loss' reached 0.69823 (best 0.69823), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=76-step=3850.ckpt' as top 1
# INFO: Epoch 77, global step 3900: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 77, global step 3900: 'train_loss' was not in top 1
# INFO: Epoch 78, global step 3950: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 78, global step 3950: 'train_loss' was not in top 1
# INFO: Epoch 79, global step 4000: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 79, global step 4000: 'train_loss' was not in top 1
# INFO: Epoch 80, global step 4050: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 80, global step 4050: 'train_loss' was not in top 1
# INFO: Epoch 81, global step 4100: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 81, global step 4100: 'train_loss' was not in top 1
# INFO: Epoch 82, global step 4150: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 82, global step 4150: 'train_loss' was not in top 1
# INFO: Epoch 83, global step 4200: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 83, global step 4200: 'train_loss' was not in top 1
# INFO: Epoch 84, global step 4250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 84, global step 4250: 'train_loss' was not in top 1
# INFO: Epoch 85, global step 4300: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 85, global step 4300: 'train_loss' was not in top 1
# INFO: Epoch 86, global step 4350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 86, global step 4350: 'train_loss' was not in top 1
# INFO: Epoch 87, global step 4400: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 87, global step 4400: 'train_loss' was not in top 1
# INFO: Epoch 88, global step 4450: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 88, global step 4450: 'train_loss' was not in top 1
# INFO: Epoch 89, global step 4500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 89, global step 4500: 'train_loss' was not in top 1
# INFO: Epoch 90, global step 4550: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 90, global step 4550: 'train_loss' was not in top 1
# INFO: Epoch 91, global step 4600: 'train_loss' reached 0.69216 (best 0.69216), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=91-step=4600.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 91, global step 4600: 'train_loss' reached 0.69216 (best 0.69216), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=91-step=4600.ckpt' as top 1
# INFO: Epoch 92, global step 4650: 'train_loss' reached 0.64577 (best 0.64577), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=92-step=4650.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 92, global step 4650: 'train_loss' reached 0.64577 (best 0.64577), saving model to '/content/lag-llama/lightning_logs/version_11/checkpoints/epoch=92-step=4650.ckpt' as top 1
# INFO: Epoch 93, global step 4700: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 93, global step 4700: 'train_loss' was not in top 1
# INFO: Epoch 94, global step 4750: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 94, global step 4750: 'train_loss' was not in top 1
# INFO: Epoch 95, global step 4800: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 95, global step 4800: 'train_loss' was not in top 1
# INFO: Epoch 96, global step 4850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 96, global step 4850: 'train_loss' was not in top 1
# INFO: Epoch 97, global step 4900: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 97, global step 4900: 'train_loss' was not in top 1
# INFO: Epoch 98, global step 4950: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 98, global step 4950: 'train_loss' was not in top 1
# INFO: Epoch 99, global step 5000: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 99, global step 5000: 'train_loss' was not in top 1
# INFO: `Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# /usr/local/lib/python3.12/dist-packages/gluonts/torch/util.py:205: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:345.)
#   return a[idx]
# number_of_people       float32
# goc_long_benchmark     float32
# goc_long_benchmark1    float32
# goc_2y_benchmark       float32
# goc_3y_benchmark       float32
# goc_5y_benchmark       float32
# goc_7y_benchmark       float32
# goc_10y_benchmark      float32
# goc_avg_over10y        float32
# spread_10y_2y          float32
# spread_10y_5y          float32
# V39079                 float32
# AVGINTWO               float32
# TBCDN30DMID            float32
# TBCDN90DMID            float32
# TBCDN180DMID           float32
# TBCDN1YMID             float32
# FXUSDCAD               float32
# FXEURCAD               float32
# EURUSD                 float32
# dtype: object
# float32
#
# 📊 Generating Forecasts...
# ✅ Forecast complete!
#
# Forecast Summary:
#   • Mean forecast: 256.01
#   • Min forecast: 198.19
#   • Max forecast: 304.33

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import os
import warnings

# ---------------------------------------------------------------------------
# CRITICAL FIX: Patch torch.load ONCE at module level
# ---------------------------------------------------------------------------
import torch.serialization

if not hasattr(torch.serialization, '_original_torch_load_backup'):
    torch.serialization._original_torch_load_backup = torch.serialization.load

def safe_torch_load(*args, **kwargs):
    """Wrapper that adds weights_only=False by default"""
    if 'weights_only' not in kwargs:
        kwargs['weights_only'] = False
    return torch.serialization._original_torch_load_backup(*args, **kwargs)

# Apply the patch
torch.load = safe_torch_load
torch.serialization.load = safe_torch_load

print("✓ torch.load patched successfully")

# GluonTS imports
from gluonts.dataset.pandas import PandasDataset
from gluonts.evaluation import make_evaluation_predictions, Evaluator
from lag_llama.gluon.estimator import LagLlamaEstimator

# ---------------------------------------------------------------------------
# 1. LOAD AND PREPROCESS DATA
# ---------------------------------------------------------------------------
filename = '/content/macro_index_data-3.csv'

if not os.path.exists(filename):
    filename = 'macro_index_data.csv'

if not os.path.exists(filename):
    print(f"❌ Error: {filename} not found. Please upload your CSV file.")
    raise FileNotFoundError("Please upload macro_index_data.csv")

df = pd.read_csv(filename)
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
df = df.asfreq('W-SUN')
df = df.ffill().bfill()

# CRITICAL: Convert all numeric data to float32
num_cols = df.select_dtypes(include=[np.number]).columns
df[num_cols] = df[num_cols].astype('float32')

print(f"✓ Data Loaded. Shape: {df.shape}")
print(f"✓ Date range: {df.index[0]} to {df.index[-1]}")

# ---------------------------------------------------------------------------
# 2. FEATURE SELECTION
# ---------------------------------------------------------------------------
target_col = 'number_of_people_MA4'

# OPTION: Use NO exogenous features (univariate forecasting)
use_exogenous = False

if use_exogenous:
    selected_features = [
        'FXUSDCAD', 'FXEURCAD', 'CPIAUCSL', 'DTWEXBGS', 'DGS10'
    ]
    selected_features = [f for f in selected_features if f in df.columns]
    print(f"\n✓ Using {len(selected_features)} exogenous features")
else:
    selected_features = []
    print(f"\n✓ Using UNIVARIATE forecasting (no exogenous features)")

# ---------------------------------------------------------------------------
# 3. PROPER TRAIN/TEST SPLIT
# ---------------------------------------------------------------------------
prediction_length = 12
context_length = 32

# Split data properly - reserve last 12 weeks for testing
split_point = len(df) - prediction_length

train_df = df.iloc[:split_point]
test_df = df.iloc[:split_point]  # TEST DATASET SHOULD NOT INCLUDE FUTURE DATA

print(f"\n✓ Train dataset: {len(train_df)} weeks (up to {train_df.index[-1]})")
print(f"✓ Holdout period: {prediction_length} weeks (from {df.index[split_point]})")
print(f"✓ Last actual value in training: {train_df[target_col].iloc[-1]:.2f}")

# Create datasets
if selected_features:
    train_ds = PandasDataset(train_df, target=target_col, feat_dynamic_real=selected_features, freq="W-SUN")
    test_ds = PandasDataset(test_df, target=target_col, feat_dynamic_real=selected_features, freq="W-SUN")
else:
    train_ds = PandasDataset(train_df, target=target_col, freq="W-SUN")
    test_ds = PandasDataset(test_df, target=target_col, freq="W-SUN")

# ---------------------------------------------------------------------------
# 4. LOAD AND FINE-TUNE MODEL
# ---------------------------------------------------------------------------
print("\nDownloading Lag-Llama checkpoint...")
# !huggingface-cli download time-series-foundation-models/Lag-Llama lag-llama.ckpt --local-dir .

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"✓ Using device: {device}")

ckpt_path = "lag-llama.ckpt"
ckpt = torch.load(ckpt_path, map_location=device)
estimator_args = ckpt["hyper_parameters"]["model_kwargs"]

estimator = LagLlamaEstimator(
    ckpt_path=ckpt_path,
    prediction_length=prediction_length,
    context_length=context_length,
    n_layer=estimator_args["n_layer"],
    n_embd_per_head=estimator_args["n_embd_per_head"],
    n_head=estimator_args["n_head"],
    scaling=estimator_args["scaling"],
    time_feat=estimator_args["time_feat"],
    aug_prob=0.0,  # Disable augmentations
    batch_size=16,  # Reduced for stability
    num_parallel_samples=100,
    trainer_kwargs={
        "accelerator": device,
        "max_epochs": 50,  # Reduced to prevent overfitting
    },
)

print("\n🚀 Starting Fine-Tuning...")
predictor = estimator.train(
    training_data=train_ds,
    cache_data=True,
    shuffle_buffer_length=1000
)

# ---------------------------------------------------------------------------
# 5. PREDICT AND EVALUATE
# ---------------------------------------------------------------------------
print("\n📊 Generating Forecasts...")
forecast_it, ts_it = make_evaluation_predictions(
    dataset=test_ds,
    predictor=predictor,
    num_samples=100
)

forecasts = list(forecast_it)
tss = list(ts_it)

# Get actual values for the forecast period
actual_values = df[target_col].iloc[split_point:split_point + prediction_length].values

# ---------------------------------------------------------------------------
# 6. CALCULATE METRICS
# ---------------------------------------------------------------------------
ts_entry = tss[0]
forecast_entry = forecasts[0]
forecast_mean = forecast_entry.mean

# Calculate errors
mae = np.mean(np.abs(forecast_mean - actual_values))
rmse = np.sqrt(np.mean((forecast_mean - actual_values) ** 2))
mape = np.mean(np.abs((actual_values - forecast_mean) / actual_values)) * 100

# ---------------------------------------------------------------------------
# 7. PLOT RESULTS
# ---------------------------------------------------------------------------
import matplotlib.dates as mdates

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10))

# ========== PLOT 1: FORECAST WITH HISTORICAL CONTEXT ==========
ts_index = ts_entry[-100:].index.to_timestamp()
ts_values = ts_entry[-100:].values

ax1.plot(ts_index, ts_values, label="Historical Data", linewidth=2,
         color='#2E86AB', marker='o', markersize=3, alpha=0.8)

forecast_index = forecast_entry.index.to_timestamp()

# Plot actual values in forecast period
actual_index = df.index[split_point:split_point + prediction_length]
ax1.plot(actual_index, actual_values, label="Actual (Holdout)",
         linewidth=2.5, color='#E63946', marker='o', markersize=5)

# Plot forecast
ax1.plot(forecast_index, forecast_mean, label="Forecast Mean",
         linewidth=2.5, color='#06A77D', marker='s', markersize=4, linestyle='--')

# Prediction intervals
q05 = forecast_entry.quantile('0.05')
q95 = forecast_entry.quantile('0.95')
ax1.fill_between(forecast_index, q05, q95, alpha=0.2, color='#06A77D',
                 label='90% Prediction Interval')

ax1.axvline(x=forecast_index[0], color='red', linestyle='--',
           linewidth=1.5, alpha=0.7, label='Forecast Start')

ax1.set_title(f"Weekly Intake Forecast vs Actual\n"
             f"MAE: {mae:.2f} | RMSE: {rmse:.2f} | MAPE: {mape:.1f}%",
             fontsize=14, fontweight='bold', pad=15)
ax1.set_xlabel("Date", fontsize=12, fontweight='bold')
ax1.set_ylabel("Number of People", fontsize=12, fontweight='bold')
ax1.legend(fontsize=9, loc='best', framealpha=0.9)
ax1.grid(True, alpha=0.3, linestyle='--')
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45, ha='right')

# ========== PLOT 2: FORECAST ERROR ANALYSIS ==========
errors = forecast_mean - actual_values
weeks = np.arange(1, prediction_length + 1)

ax2.bar(weeks, errors, color=['#06A77D' if e >= 0 else '#E63946' for e in errors],
       alpha=0.7, edgecolor='black', linewidth=1.5)
ax2.axhline(y=0, color='black', linestyle='-', linewidth=1)
ax2.set_title("Forecast Error by Week", fontsize=14, fontweight='bold', pad=15)
ax2.set_xlabel("Week Ahead", fontsize=12, fontweight='bold')
ax2.set_ylabel("Error (Forecast - Actual)", fontsize=12, fontweight='bold')
ax2.grid(True, alpha=0.3, axis='y', linestyle='--')
ax2.set_xticks(weeks)

plt.tight_layout()
plt.show()

# ---------------------------------------------------------------------------
# 8. PRINT DETAILED SUMMARY
# ---------------------------------------------------------------------------
print("\n" + "="*70)
print("✅ FORECAST EVALUATION COMPLETE!")
print("="*70)

print(f"\n📊 ACCURACY METRICS:")
print(f"  • MAE (Mean Absolute Error):        {mae:.2f}")
print(f"  • RMSE (Root Mean Squared Error):   {rmse:.2f}")
print(f"  • MAPE (Mean Absolute % Error):     {mape:.1f}%")

print(f"\n📈 FORECAST SUMMARY (Next {prediction_length} weeks):")
print(f"  • Mean Forecast:     {forecast_mean.mean():.2f}")
print(f"  • Median Forecast:   {np.median(forecast_mean):.2f}")
print(f"  • Min Forecast:      {forecast_mean.min():.2f}")
print(f"  • Max Forecast:      {forecast_mean.max():.2f}")
print(f"  • Std Deviation:     {forecast_mean.std():.2f}")

print(f"\n📉 ACTUAL VALUES (Holdout Period):")
print(f"  • Mean Actual:       {actual_values.mean():.2f}")
print(f"  • Min Actual:        {actual_values.min():.2f}")
print(f"  • Max Actual:        {actual_values.max():.2f}")

print(f"\n📋 WEEK-BY-WEEK COMPARISON:")
print(f"{'Week':<6} {'Actual':<10} {'Forecast':<10} {'Error':<10} {'% Error':<10}")
print("-" * 50)
for i, (actual, pred) in enumerate(zip(actual_values, forecast_mean), 1):
    error = pred - actual
    pct_error = (error / actual) * 100
    print(f"{i:<6} {actual:<10.2f} {pred:<10.2f} {error:<10.2f} {pct_error:<10.1f}%")

print("\n" + "="*70)
# Out:
# ✓ torch.load patched successfully
# ✓ Data Loaded. Shape: (242, 43)
# ✓ Date range: 2021-03-07 00:00:00 to 2025-10-19 00:00:00
#
# ✓ Using UNIVARIATE forecasting (no exogenous features)
#
# ✓ Train dataset: 230 weeks (up to 2025-07-27 00:00:00)
# ✓ Holdout period: 12 weeks (from 2025-08-03 00:00:00)
# ✓ Last actual value in training: 186.25
#
# Downloading Lag-Llama checkpoint...
# ⚠️  Warning: 'huggingface-cli download' is deprecated. Use 'hf download' instead.
# lag-llama.ckpt
# ✓ Using device: cuda
#
# 🚀 Starting Fine-Tuning...
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: IPU available: False, using: 0 IPUs
# INFO:lightning.pytorch.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/configuration_validator.py:74: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:
#   | Name          | Type               | Params
# -----------------------------------------------------
# 0 | model         | LagLlamaModel      | 2.4 M
# 1 | augmentations | ApplyAugmentations | 0
# -----------------------------------------------------
# 2.4 M     Trainable params
# 0         Non-trainable params
# 2.4 M     Total params
# 9.797     Total estimated model params size (MB)
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name          | Type               | Params
# -----------------------------------------------------
# 0 | model         | LagLlamaModel      | 2.4 M
# 1 | augmentations | ApplyAugmentations | 0
# -----------------------------------------------------
# 2.4 M     Trainable params
# 0         Non-trainable params
# 2.4 M     Total params
# 9.797     Total estimated model params size (MB)
# Training: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/gluonts/torch/util.py:205: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:345.)
#   return a[idx]
# INFO: Epoch 0, global step 50: 'train_loss' reached 4.19029 (best 4.19029), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=0-step=50.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 0, global step 50: 'train_loss' reached 4.19029 (best 4.19029), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=0-step=50.ckpt' as top 1
# INFO: Epoch 1, global step 100: 'train_loss' reached 3.65878 (best 3.65878), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=1-step=100.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 1, global step 100: 'train_loss' reached 3.65878 (best 3.65878), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=1-step=100.ckpt' as top 1
# INFO: Epoch 2, global step 150: 'train_loss' reached 3.38780 (best 3.38780), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=2-step=150.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 2, global step 150: 'train_loss' reached 3.38780 (best 3.38780), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=2-step=150.ckpt' as top 1
# INFO: Epoch 3, global step 200: 'train_loss' reached 3.03645 (best 3.03645), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=3-step=200.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 3, global step 200: 'train_loss' reached 3.03645 (best 3.03645), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=3-step=200.ckpt' as top 1
# INFO: Epoch 4, global step 250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 4, global step 250: 'train_loss' was not in top 1
# INFO: Epoch 5, global step 300: 'train_loss' reached 2.83104 (best 2.83104), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=5-step=300.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 5, global step 300: 'train_loss' reached 2.83104 (best 2.83104), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=5-step=300.ckpt' as top 1
# INFO: Epoch 6, global step 350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 6, global step 350: 'train_loss' was not in top 1
# INFO: Epoch 7, global step 400: 'train_loss' reached 2.59698 (best 2.59698), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=7-step=400.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 7, global step 400: 'train_loss' reached 2.59698 (best 2.59698), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=7-step=400.ckpt' as top 1
# INFO: Epoch 8, global step 450: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 8, global step 450: 'train_loss' was not in top 1
# INFO: Epoch 9, global step 500: 'train_loss' reached 2.42244 (best 2.42244), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=9-step=500.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 9, global step 500: 'train_loss' reached 2.42244 (best 2.42244), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=9-step=500.ckpt' as top 1
# INFO: Epoch 10, global step 550: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 10, global step 550: 'train_loss' was not in top 1
# INFO: Epoch 11, global step 600: 'train_loss' reached 2.27275 (best 2.27275), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=11-step=600.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 11, global step 600: 'train_loss' reached 2.27275 (best 2.27275), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=11-step=600.ckpt' as top 1
# INFO: Epoch 12, global step 650: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 12, global step 650: 'train_loss' was not in top 1
# INFO: Epoch 13, global step 700: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 13, global step 700: 'train_loss' was not in top 1
# INFO: Epoch 14, global step 750: 'train_loss' reached 2.08972 (best 2.08972), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=14-step=750.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 14, global step 750: 'train_loss' reached 2.08972 (best 2.08972), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=14-step=750.ckpt' as top 1
# INFO: Epoch 15, global step 800: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 15, global step 800: 'train_loss' was not in top 1
# INFO: Epoch 16, global step 850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 16, global step 850: 'train_loss' was not in top 1
# INFO: Epoch 17, global step 900: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 17, global step 900: 'train_loss' was not in top 1
# INFO: Epoch 18, global step 950: 'train_loss' reached 1.90416 (best 1.90416), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=18-step=950.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 18, global step 950: 'train_loss' reached 1.90416 (best 1.90416), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=18-step=950.ckpt' as top 1
# INFO: Epoch 19, global step 1000: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 19, global step 1000: 'train_loss' was not in top 1
# INFO: Epoch 20, global step 1050: 'train_loss' reached 1.89205 (best 1.89205), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=20-step=1050.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 20, global step 1050: 'train_loss' reached 1.89205 (best 1.89205), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=20-step=1050.ckpt' as top 1
# INFO: Epoch 21, global step 1100: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 21, global step 1100: 'train_loss' was not in top 1
# INFO: Epoch 22, global step 1150: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 22, global step 1150: 'train_loss' was not in top 1
# INFO: Epoch 23, global step 1200: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 23, global step 1200: 'train_loss' was not in top 1
# INFO: Epoch 24, global step 1250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 24, global step 1250: 'train_loss' was not in top 1
# INFO: Epoch 25, global step 1300: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 25, global step 1300: 'train_loss' was not in top 1
# INFO: Epoch 26, global step 1350: 'train_loss' reached 1.75740 (best 1.75740), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=26-step=1350.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 26, global step 1350: 'train_loss' reached 1.75740 (best 1.75740), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=26-step=1350.ckpt' as top 1
# INFO: Epoch 27, global step 1400: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 27, global step 1400: 'train_loss' was not in top 1
# INFO: Epoch 28, global step 1450: 'train_loss' reached 1.72991 (best 1.72991), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=28-step=1450.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 28, global step 1450: 'train_loss' reached 1.72991 (best 1.72991), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=28-step=1450.ckpt' as top 1
# INFO: Epoch 29, global step 1500: 'train_loss' reached 1.67796 (best 1.67796), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=29-step=1500.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 29, global step 1500: 'train_loss' reached 1.67796 (best 1.67796), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=29-step=1500.ckpt' as top 1
# INFO: Epoch 30, global step 1550: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 30, global step 1550: 'train_loss' was not in top 1
# INFO: Epoch 31, global step 1600: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 31, global step 1600: 'train_loss' was not in top 1
# INFO: Epoch 32, global step 1650: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 32, global step 1650: 'train_loss' was not in top 1
# INFO: Epoch 33, global step 1700: 'train_loss' reached 1.45441 (best 1.45441), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=33-step=1700.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 33, global step 1700: 'train_loss' reached 1.45441 (best 1.45441), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=33-step=1700.ckpt' as top 1
# INFO: Epoch 34, global step 1750: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 34, global step 1750: 'train_loss' was not in top 1
# INFO: Epoch 35, global step 1800: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 35, global step 1800: 'train_loss' was not in top 1
# INFO: Epoch 36, global step 1850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 36, global step 1850: 'train_loss' was not in top 1
# INFO: Epoch 37, global step 1900: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 37, global step 1900: 'train_loss' was not in top 1
# INFO: Epoch 38, global step 1950: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 38, global step 1950: 'train_loss' was not in top 1
# INFO: Epoch 39, global step 2000: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 39, global step 2000: 'train_loss' was not in top 1
# INFO: Epoch 40, global step 2050: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 40, global step 2050: 'train_loss' was not in top 1
# INFO: Epoch 41, global step 2100: 'train_loss' reached 1.44938 (best 1.44938), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=41-step=2100.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 41, global step 2100: 'train_loss' reached 1.44938 (best 1.44938), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=41-step=2100.ckpt' as top 1
# INFO: Epoch 42, global step 2150: 'train_loss' reached 1.44052 (best 1.44052), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=42-step=2150.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 42, global step 2150: 'train_loss' reached 1.44052 (best 1.44052), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=42-step=2150.ckpt' as top 1
# INFO: Epoch 43, global step 2200: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 43, global step 2200: 'train_loss' was not in top 1
# INFO: Epoch 44, global step 2250: 'train_loss' reached 1.43080 (best 1.43080), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=44-step=2250.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 44, global step 2250: 'train_loss' reached 1.43080 (best 1.43080), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=44-step=2250.ckpt' as top 1
# INFO: Epoch 45, global step 2300: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 45, global step 2300: 'train_loss' was not in top 1
# INFO: Epoch 46, global step 2350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 46, global step 2350: 'train_loss' was not in top 1
# INFO: Epoch 47, global step 2400: 'train_loss' reached 1.40578 (best 1.40578), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=47-step=2400.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 47, global step 2400: 'train_loss' reached 1.40578 (best 1.40578), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=47-step=2400.ckpt' as top 1
# INFO: Epoch 48, global step 2450: 'train_loss' reached 1.32220 (best 1.32220), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=48-step=2450.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 48, global step 2450: 'train_loss' reached 1.32220 (best 1.32220), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=48-step=2450.ckpt' as top 1
# INFO: Epoch 49, global step 2500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 49, global step 2500: 'train_loss' was not in top 1
# INFO: `Trainer.fit` stopped: `max_epochs=50` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=50` reached.
# 📊 Generating Forecasts...
# /usr/local/lib/python3.12/dist-packages/gluonts/torch/util.py:205: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:345.)
#   return a[idx]
# ======================================================================
# ✅ FORECAST EVALUATION COMPLETE!
# ======================================================================
#
# 📊 ACCURACY METRICS:
#   • MAE (Mean Absolute Error):        48.42
#   • RMSE (Root Mean Squared Error):   62.02
#   • MAPE (Mean Absolute % Error):     24.7%
#
# 📈 FORECAST SUMMARY (Next 12 weeks):
#   • Mean Forecast:     243.27
#   • Median Forecast:   235.34
#   • Min Forecast:      198.06
#   • Max Forecast:      328.14
#   • Std Deviation:     42.34
#
# 📉 ACTUAL VALUES (Holdout Period):
#   • Mean Actual:       195.31
#   • Min Actual:        180.50
#   • Max Actual:        210.00
#
# 📋 WEEK-BY-WEEK COMPARISON:
# Week   Actual     Forecast   Error      % Error
# --------------------------------------------------
# 1      210.00     328.14     118.14     56.3      %
# 2      199.75     322.90     123.15     61.7      %
# 3      205.25     273.99     68.74      33.5      %
# 4      207.75     243.29     35.54      17.1      %
# 5      190.25     240.02     49.77      26.2      %
# 6      180.50     234.95     54.45      30.2      %
# 7      182.75     235.72     52.97      29.0      %
# 8      184.50     230.63     46.13      25.0      %
# 9      181.25     206.76     25.51      14.1      %
# 10     203.50     201.88     -1.62      -0.8      %
# 11     204.00     202.84     -1.16      -0.6      %
# 12     194.25     198.06     3.81       2.0       %
#
# ======================================================================

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import os
import warnings

# ---------------------------------------------------------------------------
# CRITICAL FIX: Patch torch.load ONCE at module level
# ---------------------------------------------------------------------------
import torch.serialization

if not hasattr(torch.serialization, '_original_torch_load_backup'):
    torch.serialization._original_torch_load_backup = torch.serialization.load

def safe_torch_load(*args, **kwargs):
    """Wrapper that adds weights_only=False by default"""
    if 'weights_only' not in kwargs:
        kwargs['weights_only'] = False
    return torch.serialization._original_torch_load_backup(*args, **kwargs)

# Apply the patch
torch.load = safe_torch_load
torch.serialization.load = safe_torch_load

print("✓ torch.load patched successfully")

# GluonTS imports
from gluonts.dataset.pandas import PandasDataset
from gluonts.evaluation import make_evaluation_predictions, Evaluator
from lag_llama.gluon.estimator import LagLlamaEstimator

# ---------------------------------------------------------------------------
# 1. LOAD AND PREPROCESS DATA
# ---------------------------------------------------------------------------
filename = '/content/macro_index_data-3.csv'

if not os.path.exists(filename):
    filename = 'macro_index_data.csv'

if not os.path.exists(filename):
    print(f"❌ Error: {filename} not found. Please upload your CSV file.")
    raise FileNotFoundError("Please upload macro_index_data.csv")

df = pd.read_csv(filename)
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
df = df.asfreq('W-SUN')
df = df.ffill().bfill()

# CRITICAL: Convert all numeric data to float32
num_cols = df.select_dtypes(include=[np.number]).columns
df[num_cols] = df[num_cols].astype('float32')

print(f"✓ Data Loaded. Shape: {df.shape}")
print(f"✓ Date range: {df.index[0]} to {df.index[-1]}")

# ---------------------------------------------------------------------------
# 2. FEATURE SELECTION
# ---------------------------------------------------------------------------
target_col = 'number_of_people_MA4'

# OPTION: Use NO exogenous features (univariate forecasting)
use_exogenous = True

if use_exogenous:
    # selected_features = [
    #     'FXUSDCAD', 'FXEURCAD', 'CPIAUCSL', 'DTWEXBGS', 'DGS10'
    # ]
    selected_features = [
    'FXUSDCAD',           # 0.55
    'FXEURCAD',           # 0.54
    'CPIAUCSL',           # 0.54
    'DTWEXBGS',           # 0.45
    'DGS10',              # 0.42
    'woodgreen_seniors_care_text_information',      # 0.38
    'woodgreen_employment_text_information',        # 0.37
    'goc_long_benchmark',                           # 0.35
    # 'goc_long_benchmark1',                          # 0.33
    # 'goc_avg_over10y',                              # 0.32
    # 'DFF',                # 0.32
    ]
    selected_features = [f for f in selected_features if f in df.columns]
    print(f"\n✓ Using {len(selected_features)} exogenous features")
else:
    selected_features = []
    print(f"\n✓ Using UNIVARIATE forecasting (no exogenous features)")

# ---------------------------------------------------------------------------
# 3. PROPER TRAIN/TEST SPLIT
# ---------------------------------------------------------------------------
prediction_length = 12
context_length = 32

# Split data properly - reserve last 12 weeks for testing
split_point = len(df) - prediction_length

train_df = df.iloc[:split_point]
test_df = df.iloc[:split_point]  # TEST DATASET SHOULD NOT INCLUDE FUTURE DATA

print(f"\n✓ Train dataset: {len(train_df)} weeks (up to {train_df.index[-1]})")
print(f"✓ Holdout period: {prediction_length} weeks (from {df.index[split_point]})")
print(f"✓ Last actual value in training: {train_df[target_col].iloc[-1]:.2f}")

# Create datasets
if selected_features:
    train_ds = PandasDataset(train_df, target=target_col, feat_dynamic_real=selected_features, freq="W-SUN")
    test_ds = PandasDataset(test_df, target=target_col, feat_dynamic_real=selected_features, freq="W-SUN")
else:
    train_ds = PandasDataset(train_df, target=target_col, freq="W-SUN")
    test_ds = PandasDataset(test_df, target=target_col, freq="W-SUN")

# ---------------------------------------------------------------------------
# 4. LOAD AND FINE-TUNE MODEL
# ---------------------------------------------------------------------------
print("\nDownloading Lag-Llama checkpoint...")
# !huggingface-cli download time-series-foundation-models/Lag-Llama lag-llama.ckpt --local-dir .

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"✓ Using device: {device}")

ckpt_path = "lag-llama.ckpt"
ckpt = torch.load(ckpt_path, map_location=device)
estimator_args = ckpt["hyper_parameters"]["model_kwargs"]

estimator = LagLlamaEstimator(
    ckpt_path=ckpt_path,
    prediction_length=prediction_length,
    context_length=context_length,
    n_layer=estimator_args["n_layer"],
    n_embd_per_head=estimator_args["n_embd_per_head"],
    n_head=estimator_args["n_head"],
    scaling=estimator_args["scaling"],
    time_feat=estimator_args["time_feat"],
    aug_prob=0.0,  # Disable augmentations
    batch_size=16,  # Reduced for stability
    num_parallel_samples=100,
    trainer_kwargs={
        "accelerator": device,
        "max_epochs": 50,  # Reduced to prevent overfitting
    },
)

print("\n🚀 Starting Fine-Tuning...")
predictor = estimator.train(
    training_data=train_ds,
    cache_data=True,
    shuffle_buffer_length=1000
)

# ---------------------------------------------------------------------------
# 5. PREDICT AND EVALUATE
# ---------------------------------------------------------------------------
print("\n📊 Generating Forecasts...")
forecast_it, ts_it = make_evaluation_predictions(
    dataset=test_ds,
    predictor=predictor,
    num_samples=100
)

forecasts = list(forecast_it)
tss = list(ts_it)

# Get actual values for the forecast period
actual_values = df[target_col].iloc[split_point:split_point + prediction_length].values

# ---------------------------------------------------------------------------
# 6. CALCULATE METRICS
# ---------------------------------------------------------------------------
ts_entry = tss[0]
forecast_entry = forecasts[0]
forecast_mean = forecast_entry.mean

# Calculate errors
mae = np.mean(np.abs(forecast_mean - actual_values))
rmse = np.sqrt(np.mean((forecast_mean - actual_values) ** 2))
mape = np.mean(np.abs((actual_values - forecast_mean) / actual_values)) * 100

# ---------------------------------------------------------------------------
# 7. PLOT RESULTS
# ---------------------------------------------------------------------------
import matplotlib.dates as mdates

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10))

# ========== PLOT 1: FORECAST WITH HISTORICAL CONTEXT ==========
ts_index = ts_entry[-100:].index.to_timestamp()
ts_values = ts_entry[-100:].values

ax1.plot(ts_index, ts_values, label="Historical Data", linewidth=2,
         color='#2E86AB', marker='o', markersize=3, alpha=0.8)

forecast_index = forecast_entry.index.to_timestamp()

# Plot actual values in forecast period
actual_index = df.index[split_point:split_point + prediction_length]
ax1.plot(actual_index, actual_values, label="Actual (Holdout)",
         linewidth=2.5, color='#E63946', marker='o', markersize=5)

# Plot forecast
ax1.plot(forecast_index, forecast_mean, label="Forecast Mean",
         linewidth=2.5, color='#06A77D', marker='s', markersize=4, linestyle='--')

# Prediction intervals
q05 = forecast_entry.quantile('0.05')
q95 = forecast_entry.quantile('0.95')
ax1.fill_between(forecast_index, q05, q95, alpha=0.2, color='#06A77D',
                 label='90% Prediction Interval')

ax1.axvline(x=forecast_index[0], color='red', linestyle='--',
           linewidth=1.5, alpha=0.7, label='Forecast Start')

ax1.set_title(f"Weekly Intake Forecast vs Actual\n"
             f"MAE: {mae:.2f} | RMSE: {rmse:.2f} | MAPE: {mape:.1f}%",
             fontsize=14, fontweight='bold', pad=15)
ax1.set_xlabel("Date", fontsize=12, fontweight='bold')
ax1.set_ylabel("Number of People", fontsize=12, fontweight='bold')
ax1.legend(fontsize=9, loc='best', framealpha=0.9)
ax1.grid(True, alpha=0.3, linestyle='--')
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45, ha='right')

# ========== PLOT 2: FORECAST ERROR ANALYSIS ==========
errors = forecast_mean - actual_values
weeks = np.arange(1, prediction_length + 1)

ax2.bar(weeks, errors, color=['#06A77D' if e >= 0 else '#E63946' for e in errors],
       alpha=0.7, edgecolor='black', linewidth=1.5)
ax2.axhline(y=0, color='black', linestyle='-', linewidth=1)
ax2.set_title("Forecast Error by Week", fontsize=14, fontweight='bold', pad=15)
ax2.set_xlabel("Week Ahead", fontsize=12, fontweight='bold')
ax2.set_ylabel("Error (Forecast - Actual)", fontsize=12, fontweight='bold')
ax2.grid(True, alpha=0.3, axis='y', linestyle='--')
ax2.set_xticks(weeks)

plt.tight_layout()
plt.show()

# ---------------------------------------------------------------------------
# 8. PRINT DETAILED SUMMARY
# ---------------------------------------------------------------------------
print("\n" + "="*70)
print("✅ FORECAST EVALUATION COMPLETE!")
print("="*70)

print(f"\n📊 ACCURACY METRICS:")
print(f"  • MAE (Mean Absolute Error):        {mae:.2f}")
print(f"  • RMSE (Root Mean Squared Error):   {rmse:.2f}")
print(f"  • MAPE (Mean Absolute % Error):     {mape:.1f}%")

print(f"\n📈 FORECAST SUMMARY (Next {prediction_length} weeks):")
print(f"  • Mean Forecast:     {forecast_mean.mean():.2f}")
print(f"  • Median Forecast:   {np.median(forecast_mean):.2f}")
print(f"  • Min Forecast:      {forecast_mean.min():.2f}")
print(f"  • Max Forecast:      {forecast_mean.max():.2f}")
print(f"  • Std Deviation:     {forecast_mean.std():.2f}")

print(f"\n📉 ACTUAL VALUES (Holdout Period):")
print(f"  • Mean Actual:       {actual_values.mean():.2f}")
print(f"  • Min Actual:        {actual_values.min():.2f}")
print(f"  • Max Actual:        {actual_values.max():.2f}")

print(f"\n📋 WEEK-BY-WEEK COMPARISON:")
print(f"{'Week':<6} {'Actual':<10} {'Forecast':<10} {'Error':<10} {'% Error':<10}")
print("-" * 50)
for i, (actual, pred) in enumerate(zip(actual_values, forecast_mean), 1):
    error = pred - actual
    pct_error = (error / actual) * 100
    print(f"{i:<6} {actual:<10.2f} {pred:<10.2f} {error:<10.2f} {pct_error:<10.1f}%")

print("\n" + "="*70)
# Out:
# ✓ torch.load patched successfully
# ✓ Data Loaded. Shape: (242, 43)
# ✓ Date range: 2021-03-07 00:00:00 to 2025-10-19 00:00:00
#
# ✓ Using 8 exogenous features
#
# ✓ Train dataset: 230 weeks (up to 2025-07-27 00:00:00)
# ✓ Holdout period: 12 weeks (from 2025-08-03 00:00:00)
# ✓ Last actual value in training: 186.25
#
# Downloading Lag-Llama checkpoint...
# ⚠️  Warning: 'huggingface-cli download' is deprecated. Use 'hf download' instead.
# lag-llama.ckpt
# ✓ Using device: cuda
#
# 🚀 Starting Fine-Tuning...
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: IPU available: False, using: 0 IPUs
# INFO:lightning.pytorch.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/configuration_validator.py:74: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:
#   | Name          | Type               | Params
# -----------------------------------------------------
# 0 | model         | LagLlamaModel      | 2.4 M
# 1 | augmentations | ApplyAugmentations | 0
# -----------------------------------------------------
# 2.4 M     Trainable params
# 0         Non-trainable params
# 2.4 M     Total params
# 9.797     Total estimated model params size (MB)
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name          | Type               | Params
# -----------------------------------------------------
# 0 | model         | LagLlamaModel      | 2.4 M
# 1 | augmentations | ApplyAugmentations | 0
# -----------------------------------------------------
# 2.4 M     Trainable params
# 0         Non-trainable params
# 2.4 M     Total params
# 9.797     Total estimated model params size (MB)
# Training: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/gluonts/torch/util.py:205: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:345.)
#   return a[idx]
# INFO: Epoch 0, global step 50: 'train_loss' reached 4.19967 (best 4.19967), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=0-step=50.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 0, global step 50: 'train_loss' reached 4.19967 (best 4.19967), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=0-step=50.ckpt' as top 1
# INFO: Epoch 1, global step 100: 'train_loss' reached 3.67631 (best 3.67631), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=1-step=100.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 1, global step 100: 'train_loss' reached 3.67631 (best 3.67631), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=1-step=100.ckpt' as top 1
# INFO: Epoch 2, global step 150: 'train_loss' reached 3.25242 (best 3.25242), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=2-step=150.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 2, global step 150: 'train_loss' reached 3.25242 (best 3.25242), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=2-step=150.ckpt' as top 1
# INFO: Epoch 3, global step 200: 'train_loss' reached 3.16181 (best 3.16181), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=3-step=200.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 3, global step 200: 'train_loss' reached 3.16181 (best 3.16181), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=3-step=200.ckpt' as top 1
# INFO: Epoch 4, global step 250: 'train_loss' reached 2.84616 (best 2.84616), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=4-step=250.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 4, global step 250: 'train_loss' reached 2.84616 (best 2.84616), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=4-step=250.ckpt' as top 1
# INFO: Epoch 5, global step 300: 'train_loss' reached 2.74255 (best 2.74255), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=5-step=300.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 5, global step 300: 'train_loss' reached 2.74255 (best 2.74255), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=5-step=300.ckpt' as top 1
# INFO: Epoch 6, global step 350: 'train_loss' reached 2.60633 (best 2.60633), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=6-step=350.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 6, global step 350: 'train_loss' reached 2.60633 (best 2.60633), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=6-step=350.ckpt' as top 1
# INFO: Epoch 7, global step 400: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 7, global step 400: 'train_loss' was not in top 1
# INFO: Epoch 8, global step 450: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 8, global step 450: 'train_loss' was not in top 1
# INFO: Epoch 9, global step 500: 'train_loss' reached 2.36046 (best 2.36046), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=9-step=500.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 9, global step 500: 'train_loss' reached 2.36046 (best 2.36046), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=9-step=500.ckpt' as top 1
# INFO: Epoch 10, global step 550: 'train_loss' reached 2.27359 (best 2.27359), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=10-step=550.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 10, global step 550: 'train_loss' reached 2.27359 (best 2.27359), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=10-step=550.ckpt' as top 1
# INFO: Epoch 11, global step 600: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 11, global step 600: 'train_loss' was not in top 1
# INFO: Epoch 12, global step 650: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 12, global step 650: 'train_loss' was not in top 1
# INFO: Epoch 13, global step 700: 'train_loss' reached 2.11626 (best 2.11626), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=13-step=700.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 13, global step 700: 'train_loss' reached 2.11626 (best 2.11626), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=13-step=700.ckpt' as top 1
# INFO: Epoch 14, global step 750: 'train_loss' reached 1.99552 (best 1.99552), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=14-step=750.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 14, global step 750: 'train_loss' reached 1.99552 (best 1.99552), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=14-step=750.ckpt' as top 1
# INFO: Epoch 15, global step 800: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 15, global step 800: 'train_loss' was not in top 1
# INFO: Epoch 16, global step 850: 'train_loss' reached 1.93554 (best 1.93554), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=16-step=850.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 16, global step 850: 'train_loss' reached 1.93554 (best 1.93554), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=16-step=850.ckpt' as top 1
# INFO: Epoch 17, global step 900: 'train_loss' reached 1.83860 (best 1.83860), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=17-step=900.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 17, global step 900: 'train_loss' reached 1.83860 (best 1.83860), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=17-step=900.ckpt' as top 1
# INFO: Epoch 18, global step 950: 'train_loss' reached 1.83521 (best 1.83521), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=18-step=950.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 18, global step 950: 'train_loss' reached 1.83521 (best 1.83521), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=18-step=950.ckpt' as top 1
# INFO: Epoch 19, global step 1000: 'train_loss' reached 1.80369 (best 1.80369), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=19-step=1000.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 19, global step 1000: 'train_loss' reached 1.80369 (best 1.80369), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=19-step=1000.ckpt' as top 1
# INFO: Epoch 20, global step 1050: 'train_loss' reached 1.75601 (best 1.75601), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=20-step=1050.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 20, global step 1050: 'train_loss' reached 1.75601 (best 1.75601), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=20-step=1050.ckpt' as top 1
# INFO: Epoch 21, global step 1100: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 21, global step 1100: 'train_loss' was not in top 1
# INFO: Epoch 22, global step 1150: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 22, global step 1150: 'train_loss' was not in top 1
# INFO: Epoch 23, global step 1200: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 23, global step 1200: 'train_loss' was not in top 1
# INFO: Epoch 24, global step 1250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 24, global step 1250: 'train_loss' was not in top 1
# INFO: Epoch 25, global step 1300: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 25, global step 1300: 'train_loss' was not in top 1
# INFO: Epoch 26, global step 1350: 'train_loss' reached 1.70569 (best 1.70569), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=26-step=1350.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 26, global step 1350: 'train_loss' reached 1.70569 (best 1.70569), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=26-step=1350.ckpt' as top 1
# INFO: Epoch 27, global step 1400: 'train_loss' reached 1.53181 (best 1.53181), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=27-step=1400.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 27, global step 1400: 'train_loss' reached 1.53181 (best 1.53181), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=27-step=1400.ckpt' as top 1
# INFO: Epoch 28, global step 1450: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 28, global step 1450: 'train_loss' was not in top 1
# INFO: Epoch 29, global step 1500: 'train_loss' reached 1.52473 (best 1.52473), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=29-step=1500.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 29, global step 1500: 'train_loss' reached 1.52473 (best 1.52473), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=29-step=1500.ckpt' as top 1
# INFO: Epoch 30, global step 1550: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 30, global step 1550: 'train_loss' was not in top 1
# INFO: Epoch 31, global step 1600: 'train_loss' reached 1.50046 (best 1.50046), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=31-step=1600.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 31, global step 1600: 'train_loss' reached 1.50046 (best 1.50046), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=31-step=1600.ckpt' as top 1
# INFO: Epoch 32, global step 1650: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 32, global step 1650: 'train_loss' was not in top 1
# INFO: Epoch 33, global step 1700: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 33, global step 1700: 'train_loss' was not in top 1
# INFO: Epoch 34, global step 1750: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 34, global step 1750: 'train_loss' was not in top 1
# INFO: Epoch 35, global step 1800: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 35, global step 1800: 'train_loss' was not in top 1
# INFO: Epoch 36, global step 1850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 36, global step 1850: 'train_loss' was not in top 1
# INFO: Epoch 37, global step 1900: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 37, global step 1900: 'train_loss' was not in top 1
# INFO: Epoch 38, global step 1950: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 38, global step 1950: 'train_loss' was not in top 1
# INFO: Epoch 39, global step 2000: 'train_loss' reached 1.44239 (best 1.44239), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=39-step=2000.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 39, global step 2000: 'train_loss' reached 1.44239 (best 1.44239), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=39-step=2000.ckpt' as top 1
# INFO: Epoch 40, global step 2050: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 40, global step 2050: 'train_loss' was not in top 1
# INFO: Epoch 41, global step 2100: 'train_loss' reached 1.37602 (best 1.37602), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=41-step=2100.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 41, global step 2100: 'train_loss' reached 1.37602 (best 1.37602), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=41-step=2100.ckpt' as top 1
# INFO: Epoch 42, global step 2150: 'train_loss' reached 1.37283 (best 1.37283), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=42-step=2150.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 42, global step 2150: 'train_loss' reached 1.37283 (best 1.37283), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=42-step=2150.ckpt' as top 1
# INFO: Epoch 43, global step 2200: 'train_loss' reached 1.35709 (best 1.35709), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=43-step=2200.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 43, global step 2200: 'train_loss' reached 1.35709 (best 1.35709), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=43-step=2200.ckpt' as top 1
# INFO: Epoch 44, global step 2250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 44, global step 2250: 'train_loss' was not in top 1
# INFO: Epoch 45, global step 2300: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 45, global step 2300: 'train_loss' was not in top 1
# INFO: Epoch 46, global step 2350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 46, global step 2350: 'train_loss' was not in top 1
# INFO: Epoch 47, global step 2400: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 47, global step 2400: 'train_loss' was not in top 1
# INFO: Epoch 48, global step 2450: 'train_loss' reached 1.31278 (best 1.31278), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=48-step=2450.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 48, global step 2450: 'train_loss' reached 1.31278 (best 1.31278), saving model to '/content/lag-llama/lightning_logs/version_4/checkpoints/epoch=48-step=2450.ckpt' as top 1
# INFO: Epoch 49, global step 2500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 49, global step 2500: 'train_loss' was not in top 1
# INFO: `Trainer.fit` stopped: `max_epochs=50` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=50` reached.
# /usr/local/lib/python3.12/dist-packages/gluonts/torch/util.py:205: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:345.)
#   return a[idx]
# 📊 Generating Forecasts...
# ======================================================================
# ✅ FORECAST EVALUATION COMPLETE!
# ======================================================================
#
# 📊 ACCURACY METRICS:
#   • MAE (Mean Absolute Error):        47.69
#   • RMSE (Root Mean Squared Error):   59.39
#   • MAPE (Mean Absolute % Error):     24.4%
#
# 📈 FORECAST SUMMARY (Next 12 weeks):
#   • Mean Forecast:     242.67
#   • Median Forecast:   237.80
#   • Min Forecast:      192.23
#   • Max Forecast:      321.21
#   • Std Deviation:     38.32
#
# 📉 ACTUAL VALUES (Holdout Period):
#   • Mean Actual:       195.31
#   • Min Actual:        180.50
#   • Max Actual:        210.00
#
# 📋 WEEK-BY-WEEK COMPARISON:
# Week   Actual     Forecast   Error      % Error
# --------------------------------------------------
# 1      210.00     321.21     111.21     53.0      %
# 2      199.75     313.36     113.61     56.9      %
# 3      205.25     265.19     59.94      29.2      %
# 4      207.75     240.47     32.72      15.7      %
# 5      190.25     240.03     49.78      26.2      %
# 6      180.50     236.34     55.84      30.9      %
# 7      182.75     239.25     56.50      30.9      %
# 8      184.50     234.73     50.23      27.2      %
# 9      181.25     213.42     32.17      17.7      %
# 10     203.50     206.23     2.73       1.3       %
# 11     204.00     209.53     5.53       2.7       %
# 12     194.25     192.23     -2.02      -1.0      %
#
# ======================================================================

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.2)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 25.2 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.6.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import os
import warnings
import optuna
from optuna.visualization import plot_optimization_history, plot_param_importances

# ---------------------------------------------------------------------------
# CRITICAL FIX: Patch torch.load ONCE at module level
# ---------------------------------------------------------------------------
import torch.serialization

if not hasattr(torch.serialization, '_original_torch_load_backup'):
    torch.serialization._original_torch_load_backup = torch.serialization.load

def safe_torch_load(*args, **kwargs):
    """Wrapper that adds weights_only=False by default"""
    if 'weights_only' not in kwargs:
        kwargs['weights_only'] = False
    return torch.serialization._original_torch_load_backup(*args, **kwargs)

# Apply the patch
torch.load = safe_torch_load
torch.serialization.load = safe_torch_load

print("✓ torch.load patched successfully")

# GluonTS imports
from gluonts.dataset.pandas import PandasDataset
from gluonts.evaluation import make_evaluation_predictions, Evaluator
from lag_llama.gluon.estimator import LagLlamaEstimator

# ---------------------------------------------------------------------------
# 1. LOAD AND PREPROCESS DATA
# ---------------------------------------------------------------------------
filename = '/content/macro_index_data-3.csv'

if not os.path.exists(filename):
    filename = 'macro_index_data.csv'

if not os.path.exists(filename):
    print(f"❌ Error: {filename} not found. Please upload your CSV file.")
    raise FileNotFoundError("Please upload macro_index_data.csv")

df = pd.read_csv(filename)
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
df = df.asfreq('W-SUN')
df = df.ffill().bfill()

# CRITICAL: Convert all numeric data to float32
num_cols = df.select_dtypes(include=[np.number]).columns
df[num_cols] = df[num_cols].astype('float32')

print(f"✓ Data Loaded. Shape: {df.shape}")
print(f"✓ Date range: {df.index[0]} to {df.index[-1]}")

# ---------------------------------------------------------------------------
# 2. FEATURE SELECTION
# ---------------------------------------------------------------------------
target_col = 'number_of_people_MA4'

use_exogenous = True

if use_exogenous:
    selected_features = [
        'FXUSDCAD', 'FXEURCAD', 'CPIAUCSL', 'DTWEXBGS', 'DGS10',
        'woodgreen_seniors_care_text_information',
        'woodgreen_employment_text_information',
        'goc_long_benchmark',
    ]
    selected_features = [f for f in selected_features if f in df.columns]
    print(f"\n✓ Using {len(selected_features)} exogenous features")
else:
    selected_features = []
    print(f"\n✓ Using UNIVARIATE forecasting (no exogenous features)")

# ---------------------------------------------------------------------------
# 3. DATA SPLIT STRATEGY
# ---------------------------------------------------------------------------
prediction_length = 12

# Use validation split for hyperparameter tuning
# Train: up to -24 weeks, Val: -24 to -12, Test: last 12 weeks
full_train_end = len(df) - 24  # Reserve last 24 weeks
val_start = full_train_end
val_end = len(df) - 12
test_start = val_end

train_df = df.iloc[:full_train_end]
val_df = df.iloc[:val_end]  # Includes train + val for proper context
test_df = df.iloc[:test_start]

print(f"\n✓ Train dataset: {len(train_df)} weeks (up to {train_df.index[-1]})")
print(f"✓ Validation period: weeks {val_start} to {val_end}")
print(f"✓ Test period: last {prediction_length} weeks")

# ---------------------------------------------------------------------------
# 4. DOWNLOAD LAG-LLAMA CHECKPOINT (ONE TIME)
# ---------------------------------------------------------------------------
ckpt_path = "lag-llama.ckpt"
if not os.path.exists(ckpt_path):
    print("\nDownloading Lag-Llama checkpoint...")
    # !huggingface-cli download time-series-foundation-models/Lag-Llama lag-llama.ckpt --local-dir .

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"✓ Using device: {device}")

# Load base checkpoint parameters
ckpt = torch.load(ckpt_path, map_location=device)
base_estimator_args = ckpt["hyper_parameters"]["model_kwargs"]

# ---------------------------------------------------------------------------
# 5. OPTUNA OBJECTIVE FUNCTION
# ---------------------------------------------------------------------------
def objective(trial):
    """
    Optuna objective function to minimize validation MAE
    """

    # Suggest hyperparameters
    context_length = trial.suggest_categorical('context_length', [16, 32, 64, 96])
    batch_size = trial.suggest_categorical('batch_size', [8, 16, 32])
    max_epochs = trial.suggest_int('max_epochs', 20, 100, step=10)
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-3, log=True)
    aug_prob = trial.suggest_float('aug_prob', 0.0, 0.3)

    # Optional: tune model architecture (if you want deeper optimization)
    # n_layer = trial.suggest_int('n_layer', 4, 12)
    # n_head = trial.suggest_int('n_head', 4, 16)

    try:
        # Create datasets
        if selected_features:
            train_ds = PandasDataset(train_df, target=target_col,
                                    feat_dynamic_real=selected_features, freq="W-SUN")
            val_ds = PandasDataset(val_df, target=target_col,
                                  feat_dynamic_real=selected_features, freq="W-SUN")
        else:
            train_ds = PandasDataset(train_df, target=target_col, freq="W-SUN")
            val_ds = PandasDataset(val_df, target=target_col, freq="W-SUN")

        # Create estimator with trial hyperparameters
        estimator = LagLlamaEstimator(
            ckpt_path=ckpt_path,
            prediction_length=prediction_length,
            context_length=context_length,
            n_layer=base_estimator_args["n_layer"],  # Or use trial.suggest_int
            n_embd_per_head=base_estimator_args["n_embd_per_head"],
            n_head=base_estimator_args["n_head"],  # Or use trial.suggest_int
            scaling=base_estimator_args["scaling"],
            time_feat=base_estimator_args["time_feat"],
            aug_prob=aug_prob,
            batch_size=batch_size,
            num_parallel_samples=100,
            lr=learning_rate,
            trainer_kwargs={
                "accelerator": device,
                "max_epochs": max_epochs,
                "enable_progress_bar": False,  # Cleaner output
            },
        )

        # Train model
        predictor = estimator.train(
            training_data=train_ds,
            cache_data=True,
            shuffle_buffer_length=1000
        )

        # Generate forecasts on validation set
        forecast_it, ts_it = make_evaluation_predictions(
            dataset=val_ds,
            predictor=predictor,
            num_samples=100
        )

        forecasts = list(forecast_it)
        tss = list(ts_it)

        # Get actual values for validation period
        actual_values = df[target_col].iloc[val_start:val_end].values
        forecast_mean = forecasts[0].mean

        # Calculate MAE as optimization metric
        mae = np.mean(np.abs(forecast_mean - actual_values))

        # Also calculate RMSE for reference
        rmse = np.sqrt(np.mean((forecast_mean - actual_values) ** 2))

        # Report intermediate value for pruning
        trial.report(mae, step=max_epochs)

        # Handle pruning
        if trial.should_prune():
            raise optuna.TrialPruned()

        print(f"Trial {trial.number}: MAE={mae:.2f}, RMSE={rmse:.2f}")

        return mae

    except Exception as e:
        print(f"Trial {trial.number} failed: {str(e)}")
        return float('inf')  # Return worst possible score on failure

# ---------------------------------------------------------------------------
# 6. RUN OPTUNA OPTIMIZATION
# ---------------------------------------------------------------------------
print("\n" + "="*70)
print("🚀 STARTING HYPERPARAMETER OPTIMIZATION WITH OPTUNA")
print("="*70 + "\n")

# Create study
study = optuna.create_study(
    direction='minimize',  # Minimize MAE
    sampler=optuna.samplers.TPESampler(seed=42),  # Tree-structured Parzen Estimator
    pruner=optuna.pruners.MedianPruner(n_warmup_steps=5),  # Prune bad trials early
)

# Run optimization
n_trials = 50  # Adjust based on your computational budget
study.optimize(objective, n_trials=n_trials, timeout=None, show_progress_bar=True)

# ---------------------------------------------------------------------------
# 7. ANALYZE RESULTS
# ---------------------------------------------------------------------------
print("\n" + "="*70)
print("✅ OPTIMIZATION COMPLETE!")
print("="*70 + "\n")

print("🏆 BEST HYPERPARAMETERS:")
print("-" * 50)
for key, value in study.best_params.items():
    print(f"  • {key}: {value}")

print(f"\n📊 BEST VALIDATION MAE: {study.best_value:.2f}")
print(f"📈 Total trials completed: {len(study.trials)}")

# Get statistics
completed_trials = [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE]
pruned_trials = [t for t in study.trials if t.state == optuna.trial.TrialState.PRUNED]

print(f"✓ Completed: {len(completed_trials)}")
print(f"✗ Pruned: {len(pruned_trials)}")

# ---------------------------------------------------------------------------
# 8. VISUALIZE OPTIMIZATION HISTORY
# ---------------------------------------------------------------------------
fig, axes = plt.subplots(2, 1, figsize=(12, 10))

# Plot 1: Optimization History
ax1 = axes[0]
trial_numbers = [t.number for t in completed_trials]
trial_values = [t.value for t in completed_trials]

ax1.plot(trial_numbers, trial_values, 'o-', alpha=0.6, linewidth=1, markersize=4)
ax1.axhline(y=study.best_value, color='r', linestyle='--', linewidth=2,
           label=f'Best MAE: {study.best_value:.2f}')
ax1.set_xlabel('Trial Number', fontsize=12, fontweight='bold')
ax1.set_ylabel('Validation MAE', fontsize=12, fontweight='bold')
ax1.set_title('Optuna Optimization History', fontsize=14, fontweight='bold', pad=15)
ax1.legend()
ax1.grid(True, alpha=0.3)

# Plot 2: Parameter Importance
ax2 = axes[1]
try:
    importances = optuna.importance.get_param_importances(study)
    params = list(importances.keys())
    values = list(importances.values())

    colors = plt.cm.viridis(np.linspace(0.3, 0.9, len(params)))
    bars = ax2.barh(params, values, color=colors, edgecolor='black', linewidth=1.5)
    ax2.set_xlabel('Importance', fontsize=12, fontweight='bold')
    ax2.set_title('Hyperparameter Importance', fontsize=14, fontweight='bold', pad=15)
    ax2.grid(True, alpha=0.3, axis='x')
except:
    ax2.text(0.5, 0.5, 'Not enough trials for importance analysis',
            ha='center', va='center', fontsize=12)

plt.tight_layout()
plt.show()

# ---------------------------------------------------------------------------
# 9. TRAIN FINAL MODEL WITH BEST HYPERPARAMETERS
# ---------------------------------------------------------------------------
print("\n" + "="*70)
print("🎯 TRAINING FINAL MODEL WITH BEST HYPERPARAMETERS")
print("="*70 + "\n")

best_params = study.best_params

# Create final datasets (use all data up to test period)
final_train_df = df.iloc[:test_start]

if selected_features:
    final_train_ds = PandasDataset(final_train_df, target=target_col,
                                   feat_dynamic_real=selected_features, freq="W-SUN")
    test_ds = PandasDataset(test_df, target=target_col,
                           feat_dynamic_real=selected_features, freq="W-SUN")
else:
    final_train_ds = PandasDataset(final_train_df, target=target_col, freq="W-SUN")
    test_ds = PandasDataset(test_df, target=target_col, freq="W-SUN")

# Create final estimator
final_estimator = LagLlamaEstimator(
    ckpt_path=ckpt_path,
    prediction_length=prediction_length,
    context_length=best_params['context_length'],
    n_layer=base_estimator_args["n_layer"],
    n_embd_per_head=base_estimator_args["n_embd_per_head"],
    n_head=base_estimator_args["n_head"],
    scaling=base_estimator_args["scaling"],
    time_feat=base_estimator_args["time_feat"],
    aug_prob=best_params['aug_prob'],
    batch_size=best_params['batch_size'],
    num_parallel_samples=100,
    lr=best_params['learning_rate'],
    trainer_kwargs={
        "accelerator": device,
        "max_epochs": best_params['max_epochs'],
    },
)

# Train final model
final_predictor = final_estimator.train(
    training_data=final_train_ds,
    cache_data=True,
    shuffle_buffer_length=1000
)

# Generate final forecasts
forecast_it, ts_it = make_evaluation_predictions(
    dataset=test_ds,
    predictor=final_predictor,
    num_samples=100
)

forecasts = list(forecast_it)
tss = list(ts_it)

# Get actual test values
actual_values = df[target_col].iloc[test_start:test_start + prediction_length].values
forecast_mean = forecasts[0].mean

# Calculate final metrics
mae = np.mean(np.abs(forecast_mean - actual_values))
rmse = np.sqrt(np.mean((forecast_mean - actual_values) ** 2))
mape = np.mean(np.abs((actual_values - forecast_mean) / actual_values)) * 100

# ---------------------------------------------------------------------------
# 10. PLOT FINAL RESULTS
# ---------------------------------------------------------------------------
import matplotlib.dates as mdates

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10))

# Plot 1: Forecast with Historical Context
ts_entry = tss[0]
ts_index = ts_entry[-100:].index.to_timestamp()
ts_values = ts_entry[-100:].values

ax1.plot(ts_index, ts_values, label="Historical Data", linewidth=2,
         color='#2E86AB', marker='o', markersize=3, alpha=0.8)

forecast_entry = forecasts[0]
forecast_index = forecast_entry.index.to_timestamp()
actual_index = df.index[test_start:test_start + prediction_length]

ax1.plot(actual_index, actual_values, label="Actual (Test)",
         linewidth=2.5, color='#E63946', marker='o', markersize=5)

ax1.plot(forecast_index, forecast_mean, label="Optimized Forecast",
         linewidth=2.5, color='#06A77D', marker='s', markersize=4, linestyle='--')

q05 = forecast_entry.quantile('0.05')
q95 = forecast_entry.quantile('0.95')
ax1.fill_between(forecast_index, q05, q95, alpha=0.2, color='#06A77D',
                 label='90% Prediction Interval')

ax1.axvline(x=forecast_index[0], color='red', linestyle='--',
           linewidth=1.5, alpha=0.7, label='Forecast Start')

ax1.set_title(f"Optimized Model: Weekly Intake Forecast vs Actual\n"
             f"MAE: {mae:.2f} | RMSE: {rmse:.2f} | MAPE: {mape:.1f}%",
             fontsize=14, fontweight='bold', pad=15)
ax1.set_xlabel("Date", fontsize=12, fontweight='bold')
ax1.set_ylabel("Number of People", fontsize=12, fontweight='bold')
ax1.legend(fontsize=9, loc='best', framealpha=0.9)
ax1.grid(True, alpha=0.3, linestyle='--')
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45, ha='right')

# Plot 2: Forecast Error Analysis
errors = forecast_mean - actual_values
weeks = np.arange(1, prediction_length + 1)

ax2.bar(weeks, errors, color=['#06A77D' if e >= 0 else '#E63946' for e in errors],
       alpha=0.7, edgecolor='black', linewidth=1.5)
ax2.axhline(y=0, color='black', linestyle='-', linewidth=1)
ax2.set_title("Forecast Error by Week", fontsize=14, fontweight='bold', pad=15)
ax2.set_xlabel("Week Ahead", fontsize=12, fontweight='bold')
ax2.set_ylabel("Error (Forecast - Actual)", fontsize=12, fontweight='bold')
ax2.grid(True, alpha=0.3, axis='y', linestyle='--')
ax2.set_xticks(weeks)

plt.tight_layout()
plt.show()

# ---------------------------------------------------------------------------
# 11. FINAL SUMMARY
# ---------------------------------------------------------------------------
print("\n" + "="*70)
print("✅ FINAL MODEL EVALUATION (TEST SET)")
print("="*70)

print(f"\n📊 ACCURACY METRICS:")
print(f"  • MAE (Mean Absolute Error):        {mae:.2f}")
print(f"  • RMSE (Root Mean Squared Error):   {rmse:.2f}")
print(f"  • MAPE (Mean Absolute % Error):     {mape:.1f}%")

print(f"\n🏆 BEST HYPERPARAMETERS USED:")
for key, value in best_params.items():
    print(f"  • {key}: {value}")

print(f"\n📋 WEEK-BY-WEEK COMPARISON:")
print(f"{'Week':<6} {'Actual':<10} {'Forecast':<10} {'Error':<10} {'% Error':<10}")
print("-" * 50)
for i, (actual, pred) in enumerate(zip(actual_values, forecast_mean), 1):
    error = pred - actual
    pct_error = (error / actual) * 100
    print(f"{i:<6} {actual:<10.2f} {pred:<10.2f} {error:<10.2f} {pct_error:<10.1f}%")

print("\n" + "="*70)

# Save best parameters to file
import json
with open('best_hyperparameters.json', 'w') as f:
    json.dump(best_params, f, indent=2)
print("\n💾 Best hyperparameters saved to 'best_hyperparameters.json'")
# Out:
# [I 2025-11-23 05:09:15,920] A new study created in memory with name: no-name-0ea3c578-ef8f-412b-8d8a-9d512fbe2f46
# ✓ torch.load patched successfully
# ✓ Data Loaded. Shape: (242, 43)
# ✓ Date range: 2021-03-07 00:00:00 to 2025-10-19 00:00:00
#
# ✓ Using 8 exogenous features
#
# ✓ Train dataset: 218 weeks (up to 2025-05-04 00:00:00)
# ✓ Validation period: weeks 218 to 230
# ✓ Test period: last 12 weeks
# ✓ Using device: cuda
#
# ======================================================================
# 🚀 STARTING HYPERPARAMETER OPTIMIZATION WITH OPTUNA
# ======================================================================
#   0%|          | 0/50 [00:00<?, ?it/s]
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: IPU available: False, using: 0 IPUs
# INFO:lightning.pytorch.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/configuration_validator.py:74: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:
#   | Name          | Type               | Params
# -----------------------------------------------------
# 0 | model         | LagLlamaModel      | 2.4 M
# 1 | augmentations | ApplyAugmentations | 0
# -----------------------------------------------------
# 2.4 M     Trainable params
# 0         Non-trainable params
# 2.4 M     Total params
# 9.797     Total estimated model params size (MB)
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name          | Type               | Params
# -----------------------------------------------------
# 0 | model         | LagLlamaModel      | 2.4 M
# 1 | augmentations | ApplyAugmentations | 0
# -----------------------------------------------------
# 2.4 M     Trainable params
# 0         Non-trainable params
# 2.4 M     Total params
# 9.797     Total estimated model params size (MB)
# /usr/local/lib/python3.12/dist-packages/gluonts/torch/util.py:205: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:345.)
#   return a[idx]
# INFO: Epoch 0, global step 50: 'train_loss' reached 3.76098 (best 3.76098), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=0-step=50.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 0, global step 50: 'train_loss' reached 3.76098 (best 3.76098), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=0-step=50.ckpt' as top 1
# INFO: Epoch 1, global step 100: 'train_loss' reached 3.75336 (best 3.75336), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=1-step=100.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 1, global step 100: 'train_loss' reached 3.75336 (best 3.75336), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=1-step=100.ckpt' as top 1
# INFO: Epoch 2, global step 150: 'train_loss' reached 3.26620 (best 3.26620), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=2-step=150.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 2, global step 150: 'train_loss' reached 3.26620 (best 3.26620), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=2-step=150.ckpt' as top 1
# INFO: Epoch 3, global step 200: 'train_loss' reached 3.07043 (best 3.07043), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=3-step=200.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 3, global step 200: 'train_loss' reached 3.07043 (best 3.07043), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=3-step=200.ckpt' as top 1
# INFO: Epoch 4, global step 250: 'train_loss' reached 2.78879 (best 2.78879), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=4-step=250.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 4, global step 250: 'train_loss' reached 2.78879 (best 2.78879), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=4-step=250.ckpt' as top 1
# INFO: Epoch 5, global step 300: 'train_loss' reached 2.63879 (best 2.63879), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=5-step=300.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 5, global step 300: 'train_loss' reached 2.63879 (best 2.63879), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=5-step=300.ckpt' as top 1
# INFO: Epoch 6, global step 350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 6, global step 350: 'train_loss' was not in top 1
# INFO: Epoch 7, global step 400: 'train_loss' reached 2.50803 (best 2.50803), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=7-step=400.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 7, global step 400: 'train_loss' reached 2.50803 (best 2.50803), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=7-step=400.ckpt' as top 1
# INFO: Epoch 8, global step 450: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 8, global step 450: 'train_loss' was not in top 1
# INFO: Epoch 9, global step 500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 9, global step 500: 'train_loss' was not in top 1
# INFO: Epoch 10, global step 550: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 10, global step 550: 'train_loss' was not in top 1
# INFO: Epoch 11, global step 600: 'train_loss' reached 2.24454 (best 2.24454), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=11-step=600.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 11, global step 600: 'train_loss' reached 2.24454 (best 2.24454), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=11-step=600.ckpt' as top 1
# INFO: Epoch 12, global step 650: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 12, global step 650: 'train_loss' was not in top 1
# INFO: Epoch 13, global step 700: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 13, global step 700: 'train_loss' was not in top 1
# INFO: Epoch 14, global step 750: 'train_loss' reached 2.10149 (best 2.10149), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=14-step=750.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 14, global step 750: 'train_loss' reached 2.10149 (best 2.10149), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=14-step=750.ckpt' as top 1
# INFO: Epoch 15, global step 800: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 15, global step 800: 'train_loss' was not in top 1
# INFO: Epoch 16, global step 850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 16, global step 850: 'train_loss' was not in top 1
# INFO: Epoch 17, global step 900: 'train_loss' reached 2.02635 (best 2.02635), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=17-step=900.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 17, global step 900: 'train_loss' reached 2.02635 (best 2.02635), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=17-step=900.ckpt' as top 1
# INFO: Epoch 18, global step 950: 'train_loss' reached 1.98345 (best 1.98345), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=18-step=950.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 18, global step 950: 'train_loss' reached 1.98345 (best 1.98345), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=18-step=950.ckpt' as top 1
# INFO: Epoch 19, global step 1000: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 19, global step 1000: 'train_loss' was not in top 1
# INFO: Epoch 20, global step 1050: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 20, global step 1050: 'train_loss' was not in top 1
# INFO: Epoch 21, global step 1100: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 21, global step 1100: 'train_loss' was not in top 1
# INFO: Epoch 22, global step 1150: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 22, global step 1150: 'train_loss' was not in top 1
# INFO: Epoch 23, global step 1200: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 23, global step 1200: 'train_loss' was not in top 1
# INFO: Epoch 24, global step 1250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 24, global step 1250: 'train_loss' was not in top 1
# INFO: Epoch 25, global step 1300: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 25, global step 1300: 'train_loss' was not in top 1
# INFO: Epoch 26, global step 1350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 26, global step 1350: 'train_loss' was not in top 1
# INFO: Epoch 27, global step 1400: 'train_loss' reached 1.94569 (best 1.94569), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=27-step=1400.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 27, global step 1400: 'train_loss' reached 1.94569 (best 1.94569), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=27-step=1400.ckpt' as top 1
# INFO: Epoch 28, global step 1450: 'train_loss' reached 1.80753 (best 1.80753), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=28-step=1450.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 28, global step 1450: 'train_loss' reached 1.80753 (best 1.80753), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=28-step=1450.ckpt' as top 1
# INFO: Epoch 29, global step 1500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 29, global step 1500: 'train_loss' was not in top 1
# INFO: Epoch 30, global step 1550: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 30, global step 1550: 'train_loss' was not in top 1
# INFO: Epoch 31, global step 1600: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 31, global step 1600: 'train_loss' was not in top 1
# INFO: Epoch 32, global step 1650: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 32, global step 1650: 'train_loss' was not in top 1
# INFO: Epoch 33, global step 1700: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 33, global step 1700: 'train_loss' was not in top 1
# INFO: Epoch 34, global step 1750: 'train_loss' reached 1.75156 (best 1.75156), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=34-step=1750.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 34, global step 1750: 'train_loss' reached 1.75156 (best 1.75156), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=34-step=1750.ckpt' as top 1
# INFO: Epoch 35, global step 1800: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 35, global step 1800: 'train_loss' was not in top 1
# INFO: Epoch 36, global step 1850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 36, global step 1850: 'train_loss' was not in top 1
# INFO: Epoch 37, global step 1900: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 37, global step 1900: 'train_loss' was not in top 1
# INFO: Epoch 38, global step 1950: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 38, global step 1950: 'train_loss' was not in top 1
# INFO: Epoch 39, global step 2000: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 39, global step 2000: 'train_loss' was not in top 1
# INFO: Epoch 40, global step 2050: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 40, global step 2050: 'train_loss' was not in top 1
# INFO: Epoch 41, global step 2100: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 41, global step 2100: 'train_loss' was not in top 1
# INFO: Epoch 42, global step 2150: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 42, global step 2150: 'train_loss' was not in top 1
# INFO: Epoch 43, global step 2200: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 43, global step 2200: 'train_loss' was not in top 1
# INFO: Epoch 44, global step 2250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 44, global step 2250: 'train_loss' was not in top 1
# INFO: Epoch 45, global step 2300: 'train_loss' reached 1.73977 (best 1.73977), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=45-step=2300.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 45, global step 2300: 'train_loss' reached 1.73977 (best 1.73977), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=45-step=2300.ckpt' as top 1
# INFO: Epoch 46, global step 2350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 46, global step 2350: 'train_loss' was not in top 1
# INFO: Epoch 47, global step 2400: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 47, global step 2400: 'train_loss' was not in top 1
# INFO: Epoch 48, global step 2450: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 48, global step 2450: 'train_loss' was not in top 1
# INFO: Epoch 49, global step 2500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 49, global step 2500: 'train_loss' was not in top 1
# INFO: Epoch 50, global step 2550: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 50, global step 2550: 'train_loss' was not in top 1
# INFO: Epoch 51, global step 2600: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 51, global step 2600: 'train_loss' was not in top 1
# INFO: Epoch 52, global step 2650: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 52, global step 2650: 'train_loss' was not in top 1
# INFO: Epoch 53, global step 2700: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 53, global step 2700: 'train_loss' was not in top 1
# INFO: Epoch 54, global step 2750: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 54, global step 2750: 'train_loss' was not in top 1
# INFO: Epoch 55, global step 2800: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 55, global step 2800: 'train_loss' was not in top 1
# INFO: Epoch 56, global step 2850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 56, global step 2850: 'train_loss' was not in top 1
# INFO: Epoch 57, global step 2900: 'train_loss' reached 1.54382 (best 1.54382), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=57-step=2900.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 57, global step 2900: 'train_loss' reached 1.54382 (best 1.54382), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=57-step=2900.ckpt' as top 1
# INFO: Epoch 58, global step 2950: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 58, global step 2950: 'train_loss' was not in top 1
# INFO: Epoch 59, global step 3000: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 59, global step 3000: 'train_loss' was not in top 1
# INFO: Epoch 60, global step 3050: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 60, global step 3050: 'train_loss' was not in top 1
# INFO: Epoch 61, global step 3100: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 61, global step 3100: 'train_loss' was not in top 1
# INFO: Epoch 62, global step 3150: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 62, global step 3150: 'train_loss' was not in top 1
# INFO: Epoch 63, global step 3200: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 63, global step 3200: 'train_loss' was not in top 1
# INFO: Epoch 64, global step 3250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 64, global step 3250: 'train_loss' was not in top 1
# INFO: Epoch 65, global step 3300: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 65, global step 3300: 'train_loss' was not in top 1
# INFO: Epoch 66, global step 3350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 66, global step 3350: 'train_loss' was not in top 1
# INFO: Epoch 67, global step 3400: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 67, global step 3400: 'train_loss' was not in top 1
# INFO: Epoch 68, global step 3450: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 68, global step 3450: 'train_loss' was not in top 1
# INFO: Epoch 69, global step 3500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 69, global step 3500: 'train_loss' was not in top 1
# INFO: Epoch 70, global step 3550: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 70, global step 3550: 'train_loss' was not in top 1
# INFO: Epoch 71, global step 3600: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 71, global step 3600: 'train_loss' was not in top 1
# INFO: Epoch 72, global step 3650: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 72, global step 3650: 'train_loss' was not in top 1
# INFO: Epoch 73, global step 3700: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 73, global step 3700: 'train_loss' was not in top 1
# INFO: Epoch 74, global step 3750: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 74, global step 3750: 'train_loss' was not in top 1
# INFO: Epoch 75, global step 3800: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 75, global step 3800: 'train_loss' was not in top 1
# INFO: Epoch 76, global step 3850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 76, global step 3850: 'train_loss' was not in top 1
# INFO: Epoch 77, global step 3900: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 77, global step 3900: 'train_loss' was not in top 1
# INFO: Epoch 78, global step 3950: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 78, global step 3950: 'train_loss' was not in top 1
# INFO: Epoch 79, global step 4000: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 79, global step 4000: 'train_loss' was not in top 1
# INFO: Epoch 80, global step 4050: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 80, global step 4050: 'train_loss' was not in top 1
# INFO: Epoch 81, global step 4100: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 81, global step 4100: 'train_loss' was not in top 1
# INFO: Epoch 82, global step 4150: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 82, global step 4150: 'train_loss' was not in top 1
# INFO: Epoch 83, global step 4200: 'train_loss' reached 1.45677 (best 1.45677), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=83-step=4200.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 83, global step 4200: 'train_loss' reached 1.45677 (best 1.45677), saving model to '/content/lag-llama/lightning_logs/version_5/checkpoints/epoch=83-step=4200.ckpt' as top 1
# INFO: Epoch 84, global step 4250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 84, global step 4250: 'train_loss' was not in top 1
# INFO: Epoch 85, global step 4300: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 85, global step 4300: 'train_loss' was not in top 1
# INFO: Epoch 86, global step 4350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 86, global step 4350: 'train_loss' was not in top 1
# INFO: Epoch 87, global step 4400: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 87, global step 4400: 'train_loss' was not in top 1
# INFO: Epoch 88, global step 4450: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 88, global step 4450: 'train_loss' was not in top 1
# INFO: Epoch 89, global step 4500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 89, global step 4500: 'train_loss' was not in top 1
# INFO: `Trainer.fit` stopped: `max_epochs=90` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=90` reached.
# /usr/local/lib/python3.12/dist-packages/gluonts/torch/util.py:205: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:345.)
#   return a[idx]
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# Trial 0: MAE=93.96, RMSE=103.60
# [I 2025-11-23 05:12:08,839] Trial 0 finished with value: 93.95703887939453 and parameters: {'context_length': 32, 'batch_size': 8, 'max_epochs': 90, 'learning_rate': 0.00015930522616241006, 'aug_prob': 0.21242177333881365}. Best is trial 0 with value: 93.95703887939453.
# INFO: IPU available: False, using: 0 IPUs
# INFO:lightning.pytorch.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/configuration_validator.py:74: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:
#   | Name          | Type               | Params
# -----------------------------------------------------
# 0 | model         | LagLlamaModel      | 2.4 M
# 1 | augmentations | ApplyAugmentations | 0
# -----------------------------------------------------
# 2.4 M     Trainable params
# 0         Non-trainable params
# 2.4 M     Total params
# 9.797     Total estimated model params size (MB)
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name          | Type               | Params
# -----------------------------------------------------
# 0 | model         | LagLlamaModel      | 2.4 M
# 1 | augmentations | ApplyAugmentations | 0
# -----------------------------------------------------
# 2.4 M     Trainable params
# 0         Non-trainable params
# 2.4 M     Total params
# 9.797     Total estimated model params size (MB)
# /usr/local/lib/python3.12/dist-packages/gluonts/torch/util.py:205: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:345.)
#   return a[idx]
# INFO: Epoch 0, global step 50: 'train_loss' reached 3.73547 (best 3.73547), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=0-step=50.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 0, global step 50: 'train_loss' reached 3.73547 (best 3.73547), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=0-step=50.ckpt' as top 1
# INFO: Epoch 1, global step 100: 'train_loss' reached 3.17778 (best 3.17778), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=1-step=100.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 1, global step 100: 'train_loss' reached 3.17778 (best 3.17778), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=1-step=100.ckpt' as top 1
# INFO: Epoch 2, global step 150: 'train_loss' reached 2.95206 (best 2.95206), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=2-step=150.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 2, global step 150: 'train_loss' reached 2.95206 (best 2.95206), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=2-step=150.ckpt' as top 1
# INFO: Epoch 3, global step 200: 'train_loss' reached 2.70370 (best 2.70370), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=3-step=200.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 3, global step 200: 'train_loss' reached 2.70370 (best 2.70370), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=3-step=200.ckpt' as top 1
# INFO: Epoch 4, global step 250: 'train_loss' reached 2.52617 (best 2.52617), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=4-step=250.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 4, global step 250: 'train_loss' reached 2.52617 (best 2.52617), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=4-step=250.ckpt' as top 1
# INFO: Epoch 5, global step 300: 'train_loss' reached 2.37462 (best 2.37462), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=5-step=300.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 5, global step 300: 'train_loss' reached 2.37462 (best 2.37462), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=5-step=300.ckpt' as top 1
# INFO: Epoch 6, global step 350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 6, global step 350: 'train_loss' was not in top 1
# INFO: Epoch 7, global step 400: 'train_loss' reached 2.30925 (best 2.30925), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=7-step=400.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 7, global step 400: 'train_loss' reached 2.30925 (best 2.30925), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=7-step=400.ckpt' as top 1
# INFO: Epoch 8, global step 450: 'train_loss' reached 2.21760 (best 2.21760), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=8-step=450.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 8, global step 450: 'train_loss' reached 2.21760 (best 2.21760), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=8-step=450.ckpt' as top 1
# INFO: Epoch 9, global step 500: 'train_loss' reached 2.07728 (best 2.07728), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=9-step=500.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 9, global step 500: 'train_loss' reached 2.07728 (best 2.07728), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=9-step=500.ckpt' as top 1
# INFO: Epoch 10, global step 550: 'train_loss' reached 2.00035 (best 2.00035), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=10-step=550.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 10, global step 550: 'train_loss' reached 2.00035 (best 2.00035), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=10-step=550.ckpt' as top 1
# INFO: Epoch 11, global step 600: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 11, global step 600: 'train_loss' was not in top 1
# INFO: Epoch 12, global step 650: 'train_loss' reached 1.83115 (best 1.83115), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=12-step=650.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 12, global step 650: 'train_loss' reached 1.83115 (best 1.83115), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=12-step=650.ckpt' as top 1
# INFO: Epoch 13, global step 700: 'train_loss' reached 1.74081 (best 1.74081), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=13-step=700.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 13, global step 700: 'train_loss' reached 1.74081 (best 1.74081), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=13-step=700.ckpt' as top 1
# INFO: Epoch 14, global step 750: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 14, global step 750: 'train_loss' was not in top 1
# INFO: Epoch 15, global step 800: 'train_loss' reached 1.65457 (best 1.65457), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=15-step=800.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 15, global step 800: 'train_loss' reached 1.65457 (best 1.65457), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=15-step=800.ckpt' as top 1
# INFO: Epoch 16, global step 850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 16, global step 850: 'train_loss' was not in top 1
# INFO: Epoch 17, global step 900: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 17, global step 900: 'train_loss' was not in top 1
# INFO: Epoch 18, global step 950: 'train_loss' reached 1.63725 (best 1.63725), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=18-step=950.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 18, global step 950: 'train_loss' reached 1.63725 (best 1.63725), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=18-step=950.ckpt' as top 1
# INFO: Epoch 19, global step 1000: 'train_loss' reached 1.60229 (best 1.60229), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=19-step=1000.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 19, global step 1000: 'train_loss' reached 1.60229 (best 1.60229), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=19-step=1000.ckpt' as top 1
# INFO: Epoch 20, global step 1050: 'train_loss' reached 1.47986 (best 1.47986), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=20-step=1050.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 20, global step 1050: 'train_loss' reached 1.47986 (best 1.47986), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=20-step=1050.ckpt' as top 1
# INFO: Epoch 21, global step 1100: 'train_loss' reached 1.44723 (best 1.44723), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=21-step=1100.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 21, global step 1100: 'train_loss' reached 1.44723 (best 1.44723), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=21-step=1100.ckpt' as top 1
# INFO: Epoch 22, global step 1150: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 22, global step 1150: 'train_loss' was not in top 1
# INFO: Epoch 23, global step 1200: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 23, global step 1200: 'train_loss' was not in top 1
# INFO: Epoch 24, global step 1250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 24, global step 1250: 'train_loss' was not in top 1
# INFO: Epoch 25, global step 1300: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 25, global step 1300: 'train_loss' was not in top 1
# INFO: Epoch 26, global step 1350: 'train_loss' reached 1.34113 (best 1.34113), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=26-step=1350.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 26, global step 1350: 'train_loss' reached 1.34113 (best 1.34113), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=26-step=1350.ckpt' as top 1
# INFO: Epoch 27, global step 1400: 'train_loss' reached 1.33264 (best 1.33264), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=27-step=1400.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 27, global step 1400: 'train_loss' reached 1.33264 (best 1.33264), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=27-step=1400.ckpt' as top 1
# INFO: Epoch 28, global step 1450: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 28, global step 1450: 'train_loss' was not in top 1
# INFO: Epoch 29, global step 1500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 29, global step 1500: 'train_loss' was not in top 1
# INFO: Epoch 30, global step 1550: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 30, global step 1550: 'train_loss' was not in top 1
# INFO: Epoch 31, global step 1600: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 31, global step 1600: 'train_loss' was not in top 1
# INFO: Epoch 32, global step 1650: 'train_loss' reached 1.32931 (best 1.32931), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=32-step=1650.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 32, global step 1650: 'train_loss' reached 1.32931 (best 1.32931), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=32-step=1650.ckpt' as top 1
# INFO: Epoch 33, global step 1700: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 33, global step 1700: 'train_loss' was not in top 1
# INFO: Epoch 34, global step 1750: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 34, global step 1750: 'train_loss' was not in top 1
# INFO: Epoch 35, global step 1800: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 35, global step 1800: 'train_loss' was not in top 1
# INFO: Epoch 36, global step 1850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 36, global step 1850: 'train_loss' was not in top 1
# INFO: Epoch 37, global step 1900: 'train_loss' reached 1.24052 (best 1.24052), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=37-step=1900.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 37, global step 1900: 'train_loss' reached 1.24052 (best 1.24052), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=37-step=1900.ckpt' as top 1
# INFO: Epoch 38, global step 1950: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 38, global step 1950: 'train_loss' was not in top 1
# INFO: Epoch 39, global step 2000: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 39, global step 2000: 'train_loss' was not in top 1
# INFO: Epoch 40, global step 2050: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 40, global step 2050: 'train_loss' was not in top 1
# INFO: Epoch 41, global step 2100: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 41, global step 2100: 'train_loss' was not in top 1
# INFO: Epoch 42, global step 2150: 'train_loss' reached 1.22143 (best 1.22143), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=42-step=2150.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 42, global step 2150: 'train_loss' reached 1.22143 (best 1.22143), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=42-step=2150.ckpt' as top 1
# INFO: Epoch 43, global step 2200: 'train_loss' reached 1.14432 (best 1.14432), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=43-step=2200.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 43, global step 2200: 'train_loss' reached 1.14432 (best 1.14432), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=43-step=2200.ckpt' as top 1
# INFO: Epoch 44, global step 2250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 44, global step 2250: 'train_loss' was not in top 1
# INFO: Epoch 45, global step 2300: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 45, global step 2300: 'train_loss' was not in top 1
# INFO: Epoch 46, global step 2350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 46, global step 2350: 'train_loss' was not in top 1
# INFO: Epoch 47, global step 2400: 'train_loss' reached 1.02759 (best 1.02759), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=47-step=2400.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 47, global step 2400: 'train_loss' reached 1.02759 (best 1.02759), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=47-step=2400.ckpt' as top 1
# INFO: Epoch 48, global step 2450: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 48, global step 2450: 'train_loss' was not in top 1
# INFO: Epoch 49, global step 2500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 49, global step 2500: 'train_loss' was not in top 1
# INFO: Epoch 50, global step 2550: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 50, global step 2550: 'train_loss' was not in top 1
# INFO: Epoch 51, global step 2600: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 51, global step 2600: 'train_loss' was not in top 1
# INFO: Epoch 52, global step 2650: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 52, global step 2650: 'train_loss' was not in top 1
# INFO: Epoch 53, global step 2700: 'train_loss' reached 1.02447 (best 1.02447), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=53-step=2700.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 53, global step 2700: 'train_loss' reached 1.02447 (best 1.02447), saving model to '/content/lag-llama/lightning_logs/version_6/checkpoints/epoch=53-step=2700.ckpt' as top 1
# INFO: Epoch 54, global step 2750: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 54, global step 2750: 'train_loss' was not in top 1
# INFO: Epoch 55, global step 2800: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 55, global step 2800: 'train_loss' was not in top 1
# INFO: Epoch 56, global step 2850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 56, global step 2850: 'train_loss' was not in top 1
# INFO: Epoch 57, global step 2900: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 57, global step 2900: 'train_loss' was not in top 1
# INFO: Epoch 58, global step 2950: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 58, global step 2950: 'train_loss' was not in top 1
# INFO: Epoch 59, global step 3000: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 59, global step 3000: 'train_loss' was not in top 1
# INFO: `Trainer.fit` stopped: `max_epochs=60` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=60` reached.
# /usr/local/lib/python3.12/dist-packages/gluonts/torch/util.py:205: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:345.)
#   return a[idx]
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: IPU available: False, using: 0 IPUs
# INFO:lightning.pytorch.utilities.rank_zero:IPU available: False, using: 0 IPUs
# Trial 1: MAE=182.51, RMSE=203.50
# [I 2025-11-23 05:14:24,042] Trial 1 finished with value: 182.50628662109375 and parameters: {'context_length': 32, 'batch_size': 32, 'max_epochs': 60, 'learning_rate': 7.309539835912905e-05, 'aug_prob': 0.08736874205941257}. Best is trial 0 with value: 93.95703887939453.
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/configuration_validator.py:74: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:
#   | Name          | Type               | Params
# -----------------------------------------------------
# 0 | model         | LagLlamaModel      | 2.4 M
# 1 | augmentations | ApplyAugmentations | 0
# -----------------------------------------------------
# 2.4 M     Trainable params
# 0         Non-trainable params
# 2.4 M     Total params
# 9.797     Total estimated model params size (MB)
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name          | Type               | Params
# -----------------------------------------------------
# 0 | model         | LagLlamaModel      | 2.4 M
# 1 | augmentations | ApplyAugmentations | 0
# -----------------------------------------------------
# 2.4 M     Trainable params
# 0         Non-trainable params
# 2.4 M     Total params
# 9.797     Total estimated model params size (MB)
# /usr/local/lib/python3.12/dist-packages/gluonts/torch/util.py:205: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:345.)
#   return a[idx]
# INFO: Epoch 0, global step 50: 'train_loss' reached 4.06755 (best 4.06755), saving model to '/content/lag-llama/lightning_logs/version_7/checkpoints/epoch=0-step=50.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 0, global step 50: 'train_loss' reached 4.06755 (best 4.06755), saving model to '/content/lag-llama/lightning_logs/version_7/checkpoints/epoch=0-step=50.ckpt' as top 1
# INFO: Epoch 1, global step 100: 'train_loss' reached 3.37935 (best 3.37935), saving model to '/content/lag-llama/lightning_logs/version_7/checkpoints/epoch=1-step=100.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 1, global step 100: 'train_loss' reached 3.37935 (best 3.37935), saving model to '/content/lag-llama/lightning_logs/version_7/checkpoints/epoch=1-step=100.ckpt' as top 1
# INFO: Epoch 2, global step 150: 'train_loss' reached 2.99138 (best 2.99138), saving model to '/content/lag-llama/lightning_logs/version_7/checkpoints/epoch=2-step=150.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 2, global step 150: 'train_loss' reached 2.99138 (best 2.99138), saving model to '/content/lag-llama/lightning_logs/version_7/checkpoints/epoch=2-step=150.ckpt' as top 1
# INFO: Epoch 3, global step 200: 'train_loss' reached 2.89622 (best 2.89622), saving model to '/content/lag-llama/lightning_logs/version_7/checkpoints/epoch=3-step=200.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 3, global step 200: 'train_loss' reached 2.89622 (best 2.89622), saving model to '/content/lag-llama/lightning_logs/version_7/checkpoints/epoch=3-step=200.ckpt' as top 1
# INFO: Epoch 4, global step 250: 'train_loss' reached 2.64589 (best 2.64589), saving model to '/content/lag-llama/lightning_logs/version_7/checkpoints/epoch=4-step=250.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 4, global step 250: 'train_loss' reached 2.64589 (best 2.64589), saving model to '/content/lag-llama/lightning_logs/version_7/checkpoints/epoch=4-step=250.ckpt' as top 1
# INFO: Epoch 5, global step 300: 'train_loss' reached 2.57366 (best 2.57366), saving model to '/content/lag-llama/lightning_logs/version_7/checkpoints/epoch=5-step=300.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 5, global step 300: 'train_loss' reached 2.57366 (best 2.57366), saving model to '/content/lag-llama/lightning_logs/version_7/checkpoints/epoch=5-step=300.ckpt' as top 1
# INFO: Epoch 6, global step 350: 'train_loss' reached 2.26240 (best 2.26240), saving model to '/content/lag-llama/lightning_logs/version_7/checkpoints/epoch=6-step=350.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 6, global step 350: 'train_loss' reached 2.26240 (best 2.26240), saving model to '/content/lag-llama/lightning_logs/version_7/checkpoints/epoch=6-step=350.ckpt' as top 1
# INFO: Epoch 7, global step 400: 'train_loss' reached 2.16732 (best 2.16732), saving model to '/content/lag-llama/lightning_logs/version_7/checkpoints/epoch=7-step=400.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 7, global step 400: 'train_loss' reached 2.16732 (best 2.16732), saving model to '/content/lag-llama/lightning_logs/version_7/checkpoints/epoch=7-step=400.ckpt' as top 1
# INFO: Epoch 8, global step 450: 'train_loss' reached 2.13436 (best 2.13436), saving model to '/content/lag-llama/lightning_logs/version_7/checkpoints/epoch=8-step=450.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 8, global step 450: 'train_loss' reached 2.13436 (best 2.13436), saving model to '/content/lag-llama/lightning_logs/version_7/checkpoints/epoch=8-step=450.ckpt' as top 1
# INFO: Epoch 9, global step 500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 9, global step 500: 'train_loss' was not in top 1
# INFO: Epoch 10, global step 550: 'train_loss' reached 2.11951 (best 2.11951), saving model to '/content/lag-llama/lightning_logs/version_7/checkpoints/epoch=10-step=550.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 10, global step 550: 'train_loss' reached 2.11951 (best 2.11951), saving model to '/content/lag-llama/lightning_logs/version_7/checkpoints/epoch=10-step=550.ckpt' as top 1
# INFO: Epoch 11, global step 600: 'train_loss' reached 2.04226 (best 2.04226), saving model to '/content/lag-llama/lightning_logs/version_7/checkpoints/epoch=11-step=600.ckpt' as top 1
# ...
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 18, global step 950: 'train_loss' reached 2.22374 (best 2.22374), saving model to '/content/lag-llama/lightning_logs/version_55/checkpoints/epoch=18-step=950.ckpt' as top 1
# INFO: Epoch 19, global step 1000: 'train_loss' reached 1.97629 (best 1.97629), saving model to '/content/lag-llama/lightning_logs/version_55/checkpoints/epoch=19-step=1000.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 19, global step 1000: 'train_loss' reached 1.97629 (best 1.97629), saving model to '/content/lag-llama/lightning_logs/version_55/checkpoints/epoch=19-step=1000.ckpt' as top 1
# INFO: Epoch 20, global step 1050: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 20, global step 1050: 'train_loss' was not in top 1
# INFO: Epoch 21, global step 1100: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 21, global step 1100: 'train_loss' was not in top 1
# INFO: Epoch 22, global step 1150: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 22, global step 1150: 'train_loss' was not in top 1
# INFO: Epoch 23, global step 1200: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 23, global step 1200: 'train_loss' was not in top 1
# INFO: Epoch 24, global step 1250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 24, global step 1250: 'train_loss' was not in top 1
# INFO: Epoch 25, global step 1300: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 25, global step 1300: 'train_loss' was not in top 1
# INFO: Epoch 26, global step 1350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 26, global step 1350: 'train_loss' was not in top 1
# INFO: Epoch 27, global step 1400: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 27, global step 1400: 'train_loss' was not in top 1
# INFO: Epoch 28, global step 1450: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 28, global step 1450: 'train_loss' was not in top 1
# INFO: Epoch 29, global step 1500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 29, global step 1500: 'train_loss' was not in top 1
# INFO: Epoch 30, global step 1550: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 30, global step 1550: 'train_loss' was not in top 1
# INFO: Epoch 31, global step 1600: 'train_loss' reached 1.97022 (best 1.97022), saving model to '/content/lag-llama/lightning_logs/version_55/checkpoints/epoch=31-step=1600.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 31, global step 1600: 'train_loss' reached 1.97022 (best 1.97022), saving model to '/content/lag-llama/lightning_logs/version_55/checkpoints/epoch=31-step=1600.ckpt' as top 1
# INFO: Epoch 32, global step 1650: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 32, global step 1650: 'train_loss' was not in top 1
# INFO: Epoch 33, global step 1700: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 33, global step 1700: 'train_loss' was not in top 1
# INFO: Epoch 34, global step 1750: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 34, global step 1750: 'train_loss' was not in top 1
# INFO: Epoch 35, global step 1800: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 35, global step 1800: 'train_loss' was not in top 1
# INFO: Epoch 36, global step 1850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 36, global step 1850: 'train_loss' was not in top 1
# INFO: Epoch 37, global step 1900: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 37, global step 1900: 'train_loss' was not in top 1
# INFO: Epoch 38, global step 1950: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 38, global step 1950: 'train_loss' was not in top 1
# INFO: Epoch 39, global step 2000: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 39, global step 2000: 'train_loss' was not in top 1
# INFO: Epoch 40, global step 2050: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 40, global step 2050: 'train_loss' was not in top 1
# INFO: Epoch 41, global step 2100: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 41, global step 2100: 'train_loss' was not in top 1
# INFO: Epoch 42, global step 2150: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 42, global step 2150: 'train_loss' was not in top 1
# INFO: Epoch 43, global step 2200: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 43, global step 2200: 'train_loss' was not in top 1
# INFO: Epoch 44, global step 2250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 44, global step 2250: 'train_loss' was not in top 1
# INFO: Epoch 45, global step 2300: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 45, global step 2300: 'train_loss' was not in top 1
# INFO: Epoch 46, global step 2350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 46, global step 2350: 'train_loss' was not in top 1
# INFO: Epoch 47, global step 2400: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 47, global step 2400: 'train_loss' was not in top 1
# INFO: Epoch 48, global step 2450: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 48, global step 2450: 'train_loss' was not in top 1
# INFO: Epoch 49, global step 2500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 49, global step 2500: 'train_loss' was not in top 1
# INFO: Epoch 50, global step 2550: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 50, global step 2550: 'train_loss' was not in top 1
# INFO: Epoch 51, global step 2600: 'train_loss' reached 1.73273 (best 1.73273), saving model to '/content/lag-llama/lightning_logs/version_55/checkpoints/epoch=51-step=2600.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 51, global step 2600: 'train_loss' reached 1.73273 (best 1.73273), saving model to '/content/lag-llama/lightning_logs/version_55/checkpoints/epoch=51-step=2600.ckpt' as top 1
# INFO: Epoch 52, global step 2650: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 52, global step 2650: 'train_loss' was not in top 1
# INFO: Epoch 53, global step 2700: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 53, global step 2700: 'train_loss' was not in top 1
# INFO: Epoch 54, global step 2750: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 54, global step 2750: 'train_loss' was not in top 1
# INFO: Epoch 55, global step 2800: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 55, global step 2800: 'train_loss' was not in top 1
# INFO: Epoch 56, global step 2850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 56, global step 2850: 'train_loss' was not in top 1
# INFO: Epoch 57, global step 2900: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 57, global step 2900: 'train_loss' was not in top 1
# INFO: Epoch 58, global step 2950: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 58, global step 2950: 'train_loss' was not in top 1
# INFO: Epoch 59, global step 3000: 'train_loss' reached 1.72971 (best 1.72971), saving model to '/content/lag-llama/lightning_logs/version_55/checkpoints/epoch=59-step=3000.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 59, global step 3000: 'train_loss' reached 1.72971 (best 1.72971), saving model to '/content/lag-llama/lightning_logs/version_55/checkpoints/epoch=59-step=3000.ckpt' as top 1
# INFO: Epoch 60, global step 3050: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 60, global step 3050: 'train_loss' was not in top 1
# INFO: Epoch 61, global step 3100: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 61, global step 3100: 'train_loss' was not in top 1
# INFO: Epoch 62, global step 3150: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 62, global step 3150: 'train_loss' was not in top 1
# INFO: Epoch 63, global step 3200: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 63, global step 3200: 'train_loss' was not in top 1
# INFO: Epoch 64, global step 3250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 64, global step 3250: 'train_loss' was not in top 1
# INFO: Epoch 65, global step 3300: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 65, global step 3300: 'train_loss' was not in top 1
# INFO: Epoch 66, global step 3350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 66, global step 3350: 'train_loss' was not in top 1
# INFO: Epoch 67, global step 3400: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 67, global step 3400: 'train_loss' was not in top 1
# INFO: Epoch 68, global step 3450: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 68, global step 3450: 'train_loss' was not in top 1
# INFO: Epoch 69, global step 3500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 69, global step 3500: 'train_loss' was not in top 1
# INFO: Epoch 70, global step 3550: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 70, global step 3550: 'train_loss' was not in top 1
# INFO: Epoch 71, global step 3600: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 71, global step 3600: 'train_loss' was not in top 1
# INFO: Epoch 72, global step 3650: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 72, global step 3650: 'train_loss' was not in top 1
# INFO: Epoch 73, global step 3700: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 73, global step 3700: 'train_loss' was not in top 1
# INFO: Epoch 74, global step 3750: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 74, global step 3750: 'train_loss' was not in top 1
# INFO: Epoch 75, global step 3800: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 75, global step 3800: 'train_loss' was not in top 1
# INFO: Epoch 76, global step 3850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 76, global step 3850: 'train_loss' was not in top 1
# INFO: Epoch 77, global step 3900: 'train_loss' reached 1.72196 (best 1.72196), saving model to '/content/lag-llama/lightning_logs/version_55/checkpoints/epoch=77-step=3900.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 77, global step 3900: 'train_loss' reached 1.72196 (best 1.72196), saving model to '/content/lag-llama/lightning_logs/version_55/checkpoints/epoch=77-step=3900.ckpt' as top 1
# INFO: Epoch 78, global step 3950: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 78, global step 3950: 'train_loss' was not in top 1
# INFO: Epoch 79, global step 4000: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 79, global step 4000: 'train_loss' was not in top 1
# INFO: Epoch 80, global step 4050: 'train_loss' reached 1.70949 (best 1.70949), saving model to '/content/lag-llama/lightning_logs/version_55/checkpoints/epoch=80-step=4050.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 80, global step 4050: 'train_loss' reached 1.70949 (best 1.70949), saving model to '/content/lag-llama/lightning_logs/version_55/checkpoints/epoch=80-step=4050.ckpt' as top 1
# INFO: Epoch 81, global step 4100: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 81, global step 4100: 'train_loss' was not in top 1
# INFO: Epoch 82, global step 4150: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 82, global step 4150: 'train_loss' was not in top 1
# INFO: Epoch 83, global step 4200: 'train_loss' reached 1.58701 (best 1.58701), saving model to '/content/lag-llama/lightning_logs/version_55/checkpoints/epoch=83-step=4200.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 83, global step 4200: 'train_loss' reached 1.58701 (best 1.58701), saving model to '/content/lag-llama/lightning_logs/version_55/checkpoints/epoch=83-step=4200.ckpt' as top 1
# INFO: Epoch 84, global step 4250: 'train_loss' reached 1.32072 (best 1.32072), saving model to '/content/lag-llama/lightning_logs/version_55/checkpoints/epoch=84-step=4250.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 84, global step 4250: 'train_loss' reached 1.32072 (best 1.32072), saving model to '/content/lag-llama/lightning_logs/version_55/checkpoints/epoch=84-step=4250.ckpt' as top 1
# INFO: Epoch 85, global step 4300: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 85, global step 4300: 'train_loss' was not in top 1
# INFO: Epoch 86, global step 4350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 86, global step 4350: 'train_loss' was not in top 1
# INFO: Epoch 87, global step 4400: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 87, global step 4400: 'train_loss' was not in top 1
# INFO: Epoch 88, global step 4450: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 88, global step 4450: 'train_loss' was not in top 1
# INFO: Epoch 89, global step 4500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 89, global step 4500: 'train_loss' was not in top 1
# INFO: `Trainer.fit` stopped: `max_epochs=90` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=90` reached.
# /usr/local/lib/python3.12/dist-packages/gluonts/torch/util.py:205: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:345.)
#   return a[idx]
# ======================================================================
# ✅ FINAL MODEL EVALUATION (TEST SET)
# ======================================================================
#
# 📊 ACCURACY METRICS:
#   • MAE (Mean Absolute Error):        42.05
#   • RMSE (Root Mean Squared Error):   55.53
#   • MAPE (Mean Absolute % Error):     21.4%
#
# 🏆 BEST HYPERPARAMETERS USED:
#   • context_length: 32
#   • batch_size: 8
#   • max_epochs: 90
#   • learning_rate: 0.0001528144718759014
#   • aug_prob: 0.20945495758485883
#
# 📋 WEEK-BY-WEEK COMPARISON:
# Week   Actual     Forecast   Error      % Error
# --------------------------------------------------
# 1      210.00     325.94     115.94     55.2      %
# 2      199.75     315.55     115.80     58.0      %
# 3      205.25     261.33     56.08      27.3      %
# 4      207.75     230.45     22.70      10.9      %
# 5      190.25     225.35     35.10      18.4      %
# 6      180.50     220.20     39.70      22.0      %
# 7      182.75     223.28     40.53      22.2      %
# 8      184.50     220.05     35.55      19.3      %
# 9      181.25     203.20     21.95      12.1      %
# 10     203.50     200.61     -2.89      -1.4      %
# 11     204.00     205.64     1.64       0.8       %
# 12     194.25     210.92     16.67      8.6       %
#
# ======================================================================
#
# 💾 Best hyperparameters saved to 'best_hyperparameters.json'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import os
import warnings

# ---------------------------------------------------------------------------
# CRITICAL FIX: Patch torch.load ONCE at module level
# ---------------------------------------------------------------------------
import torch.serialization

if not hasattr(torch.serialization, '_original_torch_load_backup'):
    torch.serialization._original_torch_load_backup = torch.serialization.load

def safe_torch_load(*args, **kwargs):
    """Wrapper that adds weights_only=False by default"""
    if 'weights_only' not in kwargs:
        kwargs['weights_only'] = False
    return torch.serialization._original_torch_load_backup(*args, **kwargs)

# Apply the patch
torch.load = safe_torch_load
torch.serialization.load = safe_torch_load

print("✓ torch.load patched successfully")

# GluonTS imports
from gluonts.dataset.pandas import PandasDataset
from gluonts.evaluation import make_evaluation_predictions, Evaluator
from lag_llama.gluon.estimator import LagLlamaEstimator

# ---------------------------------------------------------------------------
# 1. LOAD AND PREPROCESS DATA
# ---------------------------------------------------------------------------
filename = '/content/macro_index_data-3.csv'

if not os.path.exists(filename):
    filename = 'macro_index_data.csv'

if not os.path.exists(filename):
    print(f"❌ Error: {filename} not found. Please upload your CSV file.")
    raise FileNotFoundError("Please upload macro_index_data.csv")

df = pd.read_csv(filename)
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
df = df.asfreq('W-SUN')
df = df.ffill().bfill()

# CRITICAL: Convert all numeric data to float32
num_cols = df.select_dtypes(include=[np.number]).columns
df[num_cols] = df[num_cols].astype('float32')

print(f"✓ Data Loaded. Shape: {df.shape}")
print(f"✓ Date range: {df.index[0]} to {df.index[-1]}")

# ---------------------------------------------------------------------------
# 2. FEATURE SELECTION
# ---------------------------------------------------------------------------
target_col = 'number_of_people'

# OPTION: Use NO exogenous features (univariate forecasting)
use_exogenous = True

if use_exogenous:
    selected_features = [
    'FXUSDCAD',           # 0.55
    'FXEURCAD',           # 0.54
    'CPIAUCSL',           # 0.54
    'DTWEXBGS',           # 0.45
    'DGS10',              # 0.42
    ]
    selected_features = [f for f in selected_features if f in df.columns]
    print(f"\n✓ Using {len(selected_features)} exogenous features")
else:
    selected_features = []
    print(f"\n✓ Using UNIVARIATE forecasting (no exogenous features)")

# ---------------------------------------------------------------------------
# 3. PROPER TRAIN/TEST SPLIT
# ---------------------------------------------------------------------------
prediction_length = 12
context_length = 32

# Split data properly - reserve last 12 weeks for testing
split_point = len(df) - prediction_length

train_df = df.iloc[:split_point]
test_df = df.iloc[:split_point]  # TEST DATASET SHOULD NOT INCLUDE FUTURE DATA

print(f"\n✓ Train dataset: {len(train_df)} weeks (up to {train_df.index[-1]})")
print(f"✓ Holdout period: {prediction_length} weeks (from {df.index[split_point]})")
print(f"✓ Last actual value in training: {train_df[target_col].iloc[-1]:.2f}")

# Create datasets
if selected_features:
    train_ds = PandasDataset(train_df, target=target_col, feat_dynamic_real=selected_features, freq="W-SUN")
    test_ds = PandasDataset(test_df, target=target_col, feat_dynamic_real=selected_features, freq="W-SUN")
else:
    train_ds = PandasDataset(train_df, target=target_col, freq="W-SUN")
    test_ds = PandasDataset(test_df, target=target_col, freq="W-SUN")

# ---------------------------------------------------------------------------
# 4. LOAD AND FINE-TUNE MODEL
# ---------------------------------------------------------------------------
print("\nDownloading Lag-Llama checkpoint...")
# !huggingface-cli download time-series-foundation-models/Lag-Llama lag-llama.ckpt --local-dir .

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"✓ Using device: {device}")

ckpt_path = "lag-llama.ckpt"
ckpt = torch.load(ckpt_path, map_location=device)
estimator_args = ckpt["hyper_parameters"]["model_kwargs"]

estimator = LagLlamaEstimator(
    ckpt_path=ckpt_path,
    prediction_length=prediction_length,
    context_length=context_length,
    n_layer=estimator_args["n_layer"],
    n_embd_per_head=estimator_args["n_embd_per_head"],
    n_head=estimator_args["n_head"],
    scaling=estimator_args["scaling"],
    time_feat=estimator_args["time_feat"],
    aug_prob=0.20945495758485883,  # Disable augmentations
    batch_size=8,  # Reduced for stability
    lr=0.0001528144718759014,
    num_parallel_samples=100,
    trainer_kwargs={
        "accelerator": device,
        "max_epochs": 90,  # Reduced to prevent overfitting
    },
)

print("\n🚀 Starting Fine-Tuning...")
predictor = estimator.train(
    training_data=train_ds,
    cache_data=True,
    shuffle_buffer_length=1000
)

# ---------------------------------------------------------------------------
# 5. PREDICT AND EVALUATE
# ---------------------------------------------------------------------------
print("\n📊 Generating Forecasts...")
forecast_it, ts_it = make_evaluation_predictions(
    dataset=test_ds,
    predictor=predictor,
    num_samples=100
)

forecasts = list(forecast_it)
tss = list(ts_it)

# Get actual values for the forecast period
actual_values = df[target_col].iloc[split_point:split_point + prediction_length].values

# ---------------------------------------------------------------------------
# 6. CALCULATE METRICS
# ---------------------------------------------------------------------------
ts_entry = tss[0]
forecast_entry = forecasts[0]
forecast_mean = forecast_entry.mean

# Calculate errors
mae = np.mean(np.abs(forecast_mean - actual_values))
rmse = np.sqrt(np.mean((forecast_mean - actual_values) ** 2))
mape = np.mean(np.abs((actual_values - forecast_mean) / actual_values)) * 100

# ---------------------------------------------------------------------------
# 7. PLOT RESULTS
# ---------------------------------------------------------------------------
import matplotlib.dates as mdates

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10))

# ========== PLOT 1: FORECAST WITH HISTORICAL CONTEXT ==========
ts_index = ts_entry[-100:].index.to_timestamp()
ts_values = ts_entry[-100:].values

ax1.plot(ts_index, ts_values, label="Historical Data", linewidth=2,
         color='#2E86AB', marker='o', markersize=3, alpha=0.8)

forecast_index = forecast_entry.index.to_timestamp()

# Plot actual values in forecast period
actual_index = df.index[split_point:split_point + prediction_length]
ax1.plot(actual_index, actual_values, label="Actual (Holdout)",
         linewidth=2.5, color='#E63946', marker='o', markersize=5)

# Plot forecast
ax1.plot(forecast_index, forecast_mean, label="Forecast Mean",
         linewidth=2.5, color='#06A77D', marker='s', markersize=4, linestyle='--')

# Prediction intervals
q05 = forecast_entry.quantile('0.05')
q95 = forecast_entry.quantile('0.95')
ax1.fill_between(forecast_index, q05, q95, alpha=0.2, color='#06A77D',
                 label='90% Prediction Interval')

ax1.axvline(x=forecast_index[0], color='red', linestyle='--',
           linewidth=1.5, alpha=0.7, label='Forecast Start')

ax1.set_title(f"Weekly Intake Forecast vs Actual\n"
             f"MAE: {mae:.2f} | RMSE: {rmse:.2f} | MAPE: {mape:.1f}%",
             fontsize=14, fontweight='bold', pad=15)
ax1.set_xlabel("Date", fontsize=12, fontweight='bold')
ax1.set_ylabel("Number of People", fontsize=12, fontweight='bold')
ax1.legend(fontsize=9, loc='best', framealpha=0.9)
ax1.grid(True, alpha=0.3, linestyle='--')
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45, ha='right')

# ========== PLOT 2: FORECAST ERROR ANALYSIS ==========
errors = forecast_mean - actual_values
weeks = np.arange(1, prediction_length + 1)

ax2.bar(weeks, errors, color=['#06A77D' if e >= 0 else '#E63946' for e in errors],
       alpha=0.7, edgecolor='black', linewidth=1.5)
ax2.axhline(y=0, color='black', linestyle='-', linewidth=1)
ax2.set_title("Forecast Error by Week", fontsize=14, fontweight='bold', pad=15)
ax2.set_xlabel("Week Ahead", fontsize=12, fontweight='bold')
ax2.set_ylabel("Error (Forecast - Actual)", fontsize=12, fontweight='bold')
ax2.grid(True, alpha=0.3, axis='y', linestyle='--')
ax2.set_xticks(weeks)

plt.tight_layout()
plt.show()

# ---------------------------------------------------------------------------
# 8. PRINT DETAILED SUMMARY
# ---------------------------------------------------------------------------
print("\n" + "="*70)
print("✅ FORECAST EVALUATION COMPLETE!")
print("="*70)

print(f"\n📊 ACCURACY METRICS:")
print(f"  • MAE (Mean Absolute Error):        {mae:.2f}")
print(f"  • RMSE (Root Mean Squared Error):   {rmse:.2f}")
print(f"  • MAPE (Mean Absolute % Error):     {mape:.1f}%")

print(f"\n📈 FORECAST SUMMARY (Next {prediction_length} weeks):")
print(f"  • Mean Forecast:     {forecast_mean.mean():.2f}")
print(f"  • Median Forecast:   {np.median(forecast_mean):.2f}")
print(f"  • Min Forecast:      {forecast_mean.min():.2f}")
print(f"  • Max Forecast:      {forecast_mean.max():.2f}")
print(f"  • Std Deviation:     {forecast_mean.std():.2f}")

print(f"\n📉 ACTUAL VALUES (Holdout Period):")
print(f"  • Mean Actual:       {actual_values.mean():.2f}")
print(f"  • Min Actual:        {actual_values.min():.2f}")
print(f"  • Max Actual:        {actual_values.max():.2f}")

print(f"\n📋 WEEK-BY-WEEK COMPARISON:")
print(f"{'Week':<6} {'Actual':<10} {'Forecast':<10} {'Error':<10} {'% Error':<10}")
print("-" * 50)
for i, (actual, pred) in enumerate(zip(actual_values, forecast_mean), 1):
    error = pred - actual
    pct_error = (error / actual) * 100
    print(f"{i:<6} {actual:<10.2f} {pred:<10.2f} {error:<10.2f} {pct_error:<10.1f}%")

print("\n" + "="*70)
# Out:
# ✓ torch.load patched successfully
# ✓ Data Loaded. Shape: (242, 43)
# ✓ Date range: 2021-03-07 00:00:00 to 2025-10-19 00:00:00
#
# ✓ Using 5 exogenous features
#
# ✓ Train dataset: 230 weeks (up to 2025-07-27 00:00:00)
# ✓ Holdout period: 12 weeks (from 2025-08-03 00:00:00)
# ✓ Last actual value in training: 161.00
#
# Downloading Lag-Llama checkpoint...
# ⚠️  Warning: 'huggingface-cli download' is deprecated. Use 'hf download' instead.
# lag-llama.ckpt
# ✓ Using device: cuda
#
# 🚀 Starting Fine-Tuning...
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: IPU available: False, using: 0 IPUs
# INFO:lightning.pytorch.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/configuration_validator.py:74: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:
#   | Name          | Type               | Params
# -----------------------------------------------------
# 0 | model         | LagLlamaModel      | 2.4 M
# 1 | augmentations | ApplyAugmentations | 0
# -----------------------------------------------------
# 2.4 M     Trainable params
# 0         Non-trainable params
# 2.4 M     Total params
# 9.797     Total estimated model params size (MB)
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name          | Type               | Params
# -----------------------------------------------------
# 0 | model         | LagLlamaModel      | 2.4 M
# 1 | augmentations | ApplyAugmentations | 0
# -----------------------------------------------------
# 2.4 M     Trainable params
# 0         Non-trainable params
# 2.4 M     Total params
# 9.797     Total estimated model params size (MB)
# Training: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/gluonts/torch/util.py:205: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:345.)
#   return a[idx]
# INFO: Epoch 0, global step 50: 'train_loss' reached 4.82481 (best 4.82481), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=0-step=50.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 0, global step 50: 'train_loss' reached 4.82481 (best 4.82481), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=0-step=50.ckpt' as top 1
# INFO: Epoch 1, global step 100: 'train_loss' reached 4.04529 (best 4.04529), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=1-step=100.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 1, global step 100: 'train_loss' reached 4.04529 (best 4.04529), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=1-step=100.ckpt' as top 1
# INFO: Epoch 2, global step 150: 'train_loss' reached 3.39580 (best 3.39580), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=2-step=150.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 2, global step 150: 'train_loss' reached 3.39580 (best 3.39580), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=2-step=150.ckpt' as top 1
# INFO: Epoch 3, global step 200: 'train_loss' reached 3.33278 (best 3.33278), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=3-step=200.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 3, global step 200: 'train_loss' reached 3.33278 (best 3.33278), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=3-step=200.ckpt' as top 1
# INFO: Epoch 4, global step 250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 4, global step 250: 'train_loss' was not in top 1
# INFO: Epoch 5, global step 300: 'train_loss' reached 3.06263 (best 3.06263), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=5-step=300.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 5, global step 300: 'train_loss' reached 3.06263 (best 3.06263), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=5-step=300.ckpt' as top 1
# INFO: Epoch 6, global step 350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 6, global step 350: 'train_loss' was not in top 1
# INFO: Epoch 7, global step 400: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 7, global step 400: 'train_loss' was not in top 1
# INFO: Epoch 8, global step 450: 'train_loss' reached 2.81907 (best 2.81907), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=8-step=450.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 8, global step 450: 'train_loss' reached 2.81907 (best 2.81907), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=8-step=450.ckpt' as top 1
# INFO: Epoch 9, global step 500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 9, global step 500: 'train_loss' was not in top 1
# INFO: Epoch 10, global step 550: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 10, global step 550: 'train_loss' was not in top 1
# INFO: Epoch 11, global step 600: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 11, global step 600: 'train_loss' was not in top 1
# INFO: Epoch 12, global step 650: 'train_loss' reached 2.62951 (best 2.62951), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=12-step=650.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 12, global step 650: 'train_loss' reached 2.62951 (best 2.62951), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=12-step=650.ckpt' as top 1
# INFO: Epoch 13, global step 700: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 13, global step 700: 'train_loss' was not in top 1
# INFO: Epoch 14, global step 750: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 14, global step 750: 'train_loss' was not in top 1
# INFO: Epoch 15, global step 800: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 15, global step 800: 'train_loss' was not in top 1
# INFO: Epoch 16, global step 850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 16, global step 850: 'train_loss' was not in top 1
# INFO: Epoch 17, global step 900: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 17, global step 900: 'train_loss' was not in top 1
# INFO: Epoch 18, global step 950: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 18, global step 950: 'train_loss' was not in top 1
# INFO: Epoch 19, global step 1000: 'train_loss' reached 2.46254 (best 2.46254), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=19-step=1000.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 19, global step 1000: 'train_loss' reached 2.46254 (best 2.46254), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=19-step=1000.ckpt' as top 1
# INFO: Epoch 20, global step 1050: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 20, global step 1050: 'train_loss' was not in top 1
# INFO: Epoch 21, global step 1100: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 21, global step 1100: 'train_loss' was not in top 1
# INFO: Epoch 22, global step 1150: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 22, global step 1150: 'train_loss' was not in top 1
# INFO: Epoch 23, global step 1200: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 23, global step 1200: 'train_loss' was not in top 1
# INFO: Epoch 24, global step 1250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 24, global step 1250: 'train_loss' was not in top 1
# INFO: Epoch 25, global step 1300: 'train_loss' reached 2.45730 (best 2.45730), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=25-step=1300.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 25, global step 1300: 'train_loss' reached 2.45730 (best 2.45730), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=25-step=1300.ckpt' as top 1
# INFO: Epoch 26, global step 1350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 26, global step 1350: 'train_loss' was not in top 1
# INFO: Epoch 27, global step 1400: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 27, global step 1400: 'train_loss' was not in top 1
# INFO: Epoch 28, global step 1450: 'train_loss' reached 2.03842 (best 2.03842), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=28-step=1450.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 28, global step 1450: 'train_loss' reached 2.03842 (best 2.03842), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=28-step=1450.ckpt' as top 1
# INFO: Epoch 29, global step 1500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 29, global step 1500: 'train_loss' was not in top 1
# INFO: Epoch 30, global step 1550: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 30, global step 1550: 'train_loss' was not in top 1
# INFO: Epoch 31, global step 1600: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 31, global step 1600: 'train_loss' was not in top 1
# INFO: Epoch 32, global step 1650: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 32, global step 1650: 'train_loss' was not in top 1
# INFO: Epoch 33, global step 1700: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 33, global step 1700: 'train_loss' was not in top 1
# INFO: Epoch 34, global step 1750: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 34, global step 1750: 'train_loss' was not in top 1
# INFO: Epoch 35, global step 1800: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 35, global step 1800: 'train_loss' was not in top 1
# INFO: Epoch 36, global step 1850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 36, global step 1850: 'train_loss' was not in top 1
# INFO: Epoch 37, global step 1900: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 37, global step 1900: 'train_loss' was not in top 1
# INFO: Epoch 38, global step 1950: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 38, global step 1950: 'train_loss' was not in top 1
# INFO: Epoch 39, global step 2000: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 39, global step 2000: 'train_loss' was not in top 1
# INFO: Epoch 40, global step 2050: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 40, global step 2050: 'train_loss' was not in top 1
# INFO: Epoch 41, global step 2100: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 41, global step 2100: 'train_loss' was not in top 1
# INFO: Epoch 42, global step 2150: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 42, global step 2150: 'train_loss' was not in top 1
# INFO: Epoch 43, global step 2200: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 43, global step 2200: 'train_loss' was not in top 1
# INFO: Epoch 44, global step 2250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 44, global step 2250: 'train_loss' was not in top 1
# INFO: Epoch 45, global step 2300: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 45, global step 2300: 'train_loss' was not in top 1
# INFO: Epoch 46, global step 2350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 46, global step 2350: 'train_loss' was not in top 1
# INFO: Epoch 47, global step 2400: 'train_loss' reached 1.86577 (best 1.86577), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=47-step=2400.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 47, global step 2400: 'train_loss' reached 1.86577 (best 1.86577), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=47-step=2400.ckpt' as top 1
# INFO: Epoch 48, global step 2450: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 48, global step 2450: 'train_loss' was not in top 1
# INFO: Epoch 49, global step 2500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 49, global step 2500: 'train_loss' was not in top 1
# INFO: Epoch 50, global step 2550: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 50, global step 2550: 'train_loss' was not in top 1
# INFO: Epoch 51, global step 2600: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 51, global step 2600: 'train_loss' was not in top 1
# INFO: Epoch 52, global step 2650: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 52, global step 2650: 'train_loss' was not in top 1
# INFO: Epoch 53, global step 2700: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 53, global step 2700: 'train_loss' was not in top 1
# INFO: Epoch 54, global step 2750: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 54, global step 2750: 'train_loss' was not in top 1
# INFO: Epoch 55, global step 2800: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 55, global step 2800: 'train_loss' was not in top 1
# INFO: Epoch 56, global step 2850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 56, global step 2850: 'train_loss' was not in top 1
# INFO: Epoch 57, global step 2900: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 57, global step 2900: 'train_loss' was not in top 1
# INFO: Epoch 58, global step 2950: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 58, global step 2950: 'train_loss' was not in top 1
# INFO: Epoch 59, global step 3000: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 59, global step 3000: 'train_loss' was not in top 1
# INFO: Epoch 60, global step 3050: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 60, global step 3050: 'train_loss' was not in top 1
# INFO: Epoch 61, global step 3100: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 61, global step 3100: 'train_loss' was not in top 1
# INFO: Epoch 62, global step 3150: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 62, global step 3150: 'train_loss' was not in top 1
# INFO: Epoch 63, global step 3200: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 63, global step 3200: 'train_loss' was not in top 1
# INFO: Epoch 64, global step 3250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 64, global step 3250: 'train_loss' was not in top 1
# INFO: Epoch 65, global step 3300: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 65, global step 3300: 'train_loss' was not in top 1
# INFO: Epoch 66, global step 3350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 66, global step 3350: 'train_loss' was not in top 1
# INFO: Epoch 67, global step 3400: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 67, global step 3400: 'train_loss' was not in top 1
# INFO: Epoch 68, global step 3450: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 68, global step 3450: 'train_loss' was not in top 1
# INFO: Epoch 69, global step 3500: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 69, global step 3500: 'train_loss' was not in top 1
# INFO: Epoch 70, global step 3550: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 70, global step 3550: 'train_loss' was not in top 1
# INFO: Epoch 71, global step 3600: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 71, global step 3600: 'train_loss' was not in top 1
# INFO: Epoch 72, global step 3650: 'train_loss' reached 1.81828 (best 1.81828), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=72-step=3650.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 72, global step 3650: 'train_loss' reached 1.81828 (best 1.81828), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=72-step=3650.ckpt' as top 1
# INFO: Epoch 73, global step 3700: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 73, global step 3700: 'train_loss' was not in top 1
# INFO: Epoch 74, global step 3750: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 74, global step 3750: 'train_loss' was not in top 1
# INFO: Epoch 75, global step 3800: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 75, global step 3800: 'train_loss' was not in top 1
# INFO: Epoch 76, global step 3850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 76, global step 3850: 'train_loss' was not in top 1
# INFO: Epoch 77, global step 3900: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 77, global step 3900: 'train_loss' was not in top 1
# INFO: Epoch 78, global step 3950: 'train_loss' reached 1.79640 (best 1.79640), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=78-step=3950.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 78, global step 3950: 'train_loss' reached 1.79640 (best 1.79640), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=78-step=3950.ckpt' as top 1
# INFO: Epoch 79, global step 4000: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 79, global step 4000: 'train_loss' was not in top 1
# INFO: Epoch 80, global step 4050: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 80, global step 4050: 'train_loss' was not in top 1
# INFO: Epoch 81, global step 4100: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 81, global step 4100: 'train_loss' was not in top 1
# INFO: Epoch 82, global step 4150: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 82, global step 4150: 'train_loss' was not in top 1
# INFO: Epoch 83, global step 4200: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 83, global step 4200: 'train_loss' was not in top 1
# INFO: Epoch 84, global step 4250: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 84, global step 4250: 'train_loss' was not in top 1
# INFO: Epoch 85, global step 4300: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 85, global step 4300: 'train_loss' was not in top 1
# INFO: Epoch 86, global step 4350: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 86, global step 4350: 'train_loss' was not in top 1
# INFO: Epoch 87, global step 4400: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 87, global step 4400: 'train_loss' was not in top 1
# INFO: Epoch 88, global step 4450: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 88, global step 4450: 'train_loss' was not in top 1
# INFO: Epoch 89, global step 4500: 'train_loss' reached 1.78719 (best 1.78719), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=89-step=4500.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 89, global step 4500: 'train_loss' reached 1.78719 (best 1.78719), saving model to '/content/lag-llama/lightning_logs/version_1/checkpoints/epoch=89-step=4500.ckpt' as top 1
# INFO: `Trainer.fit` stopped: `max_epochs=90` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=90` reached.
# /usr/local/lib/python3.12/dist-packages/gluonts/torch/util.py:205: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:345.)
#   return a[idx]
# 📊 Generating Forecasts...
# ======================================================================
# ✅ FORECAST EVALUATION COMPLETE!
# ======================================================================
#
# 📊 ACCURACY METRICS:
#   • MAE (Mean Absolute Error):        52.99
#   • RMSE (Root Mean Squared Error):   60.95
#   • MAPE (Mean Absolute % Error):     30.6%
#
# 📈 FORECAST SUMMARY (Next 12 weeks):
#   • Mean Forecast:     218.49
#   • Median Forecast:   222.46
#   • Min Forecast:      163.19
#   • Max Forecast:      264.12
#   • Std Deviation:     35.54
#
# 📉 ACTUAL VALUES (Holdout Period):
#   • Mean Actual:       195.50
#   • Min Actual:        134.00
#   • Max Actual:        268.00
#
# 📋 WEEK-BY-WEEK COMPARISON:
# Week   Actual     Forecast   Error      % Error
# --------------------------------------------------
# 1      268.00     262.94     -5.06      -1.9      %
# 2      173.00     250.68     77.68      44.9      %
# 3      219.00     163.19     -55.81     -25.5     %
# 4      171.00     264.12     93.12      54.5      %
# 5      198.00     247.47     49.47      25.0      %
# 6      134.00     234.76     100.76     75.2      %
# 7      228.00     170.12     -57.88     -25.4     %
# 8      178.00     245.07     67.07      37.7      %
# 9      185.00     174.02     -10.98     -5.9      %
# 10     223.00     210.16     -12.84     -5.8      %
# 11     230.00     192.56     -37.44     -16.3     %
# 12     139.00     206.80     67.80      48.8      %
#
# ======================================================================
